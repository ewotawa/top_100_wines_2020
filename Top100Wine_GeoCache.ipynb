# %% [markdown]
# # GeoCache: *Wine Spectator*'s Top 100 Wines, 1988-2020
# List available online on *Wine Spectator*'s [Top 100 Lists web site](https://top100.winespectator.com/lists/).

# %% [markdown]
# ## File Setup

# %%
# import and initialize main python libraries
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# import libraries for file navigation
import os
import shutil
import glob
from pandas_ods_reader import read_ods

# import other packages
from scipy import stats
from sklearn import linear_model

# import geo packages
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon

# import Geopy packages
import geopy
from geopy.geocoders import Nominatim

# %%
# initialize vizualization set
sns.set(style="whitegrid", palette="colorblind", color_codes=True)
sns.mpl.rc("figure", figsize=(10, 6))

# Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Dataframe Exploration

# %%
# Note: save CSV files in UTF-8 format to preserve special characters.
df_Wine = pd.read_csv('./CSV_Wines.csv')
df_GeoCache = pd.read_csv('./CSV_GeoCache.csv')
df_GeoList = pd.read_csv('./CSV_GeoList.csv')

# %%
df_Wine.shape
# Out:
# (3301, 18)

# %%
df_Wine.dtypes
# Out:
# Review_Year           float64
# Rank                   object
# Vintage                object
# Score                 float64
# Price                  object
# Winemaker              object
# Wine                   object
# Wine_Style             object
# Grape_Blend            object
# Blend_List             object
# Geography              object
# Cases_Made            float64
# Cases_Imported        float64
# Reviewer               object
# Drink_now             float64
# Best_Drink_from       float64
# Best_Drink_Through    float64
# Review                 object
# dtype: object

# %%
df_GeoCache.shape
# Out:
# (1224, 3)

# %%
df_GeoList.shape
# Out:
# (445, 1)

# %%
df_Wine.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price              Winemaker  \
# 1802       2002.0    3    1997   94.0    50         Castello Banfi
# 2391       1997.0   92    1994   92.0    15                Markham
# 514        2015.0   15    2011   94.0    30        Abadia Retuerta
# 642        2014.0   43    2013   91.0    12          Charles Smith
# 2344       1997.0   45    1996   91.0    12              Rosemount
# 838        2012.0   39    2010   92.0    20  Domaines Schlumberger
# 2377       1997.0   78    1995   92.0    40         Louis Carillon
# 2260       1998.0   26    1995   97.0   135        Álvaro Palacios
# 916        2011.0   17    2006   95.0    60         Tenuta Carlina
# 1895       2002.0   96    1999   90.0    38       Château Montrose
#
#                                                    Wine Wine_Style  \
# 1802                             Brunello di Montalcino        Red
# 2391                     Cabernet Sauvignon Napa Valley        Red
# 514   Viño de la Tierra de Castilla y León Sardon de...        Red
# 642     Riesling Columbia Valley Kung Fu Girl Evergreen      White
# 2344                     Shiraz South Eastern Australia        Red
# 838                 Pinot Gris Alsace Les Princes Abbés      White
# 2377                                 Puligny-Montrachet      White
# 2260                                   Priorat L'Ermita        Red
# 916                    Brunello di Montalcino La Togata        Red
# 1895                                        St.-Estèphe        Red
#
#                          Grape_Blend                      Blend_List  \
# 1802          Brunello di Montalcino                             NaN
# 2391             Cabernet Sauvignon                              NaN
# 514                            Blend  Cabernet - Syrah – Tempranillo
# 642                         Riesling                             NaN
# 2344                  Shiraz | Syrah                             NaN
# 838        Pinot Grigio | Pinot Gris                             NaN
# 2377                     Chardonnay                              NaN
# 2260  Garnacha | Grenache | Garnatxa                             NaN
# 916           Brunello di Montalcino                             NaN
# 1895                           Blend              Bordeaux Blend Red
#
#                     Geography  Cases_Made  Cases_Imported Reviewer  Drink_now  \
# 1802   Brunello di Montalcino     32500.0             NaN       JS        NaN
# 2391              Napa Valley     13350.0             NaN       JL        NaN
# 514           Sardon de Duero     30000.0             NaN       TM        1.0
# 642           Columbia Valley    128806.0             NaN       HS        1.0
# 2344  South Eastern Australia    150000.0             NaN       HS        1.0
# 838                    Alsace         NaN          2100.0       AN        1.0
# 2377       Puligny-Montrachet      1665.0             NaN      NaN        NaN
# 2260                  Priorat       450.0             NaN       TM        1.0
# 916    Brunello di Montalcino      4000.0             NaN       BS        NaN
# 1895              St.-Estèphe     18715.0             NaN       JS        NaN
#
#       Best_Drink_from  Best_Drink_Through  \
# 1802           2003.0                 NaN
# 2391           2000.0                 NaN
# 514            2015.0              2031.0
# 642            2014.0              2020.0
# 2344           2000.0                 NaN
# 838            2012.0              2022.0
# 2377           1997.0              2005.0
# 2260           1998.0              2005.0
# 916            2013.0              2026.0
# 1895           2005.0                 NaN
#
#                                                  Review
# 1802  A Brunello for everyone. Solid and focused, wi...
# 2391  This seductive wine not only grows on you with...
# 514   Alluring for its plush texture and impressive ...
# 642   Crisp and sleek, with juicy, expansive nectari...
# 2344  Bursting with fruit, here's a lively, generous...
# 838   Finely knit, with a vibrancy to the refined ac...
# 2377  Amazing quality for a village wine, with almos...
# 2260  Such a powerful mouthful of wine that after sw...
# 916   Very pure aromas and flavors of raspberry and ...
# 1895  Very fine indeed, offering complex aromas of b...

# %%
df_GeoCache.sample(10)
# Out:
#                              Geography     Hierarchy  \
# 642                           Alicante  Hierarchy_01
# 212              Primitivo di Manduria  Hierarchy_00
# 1029  Puligny-Montrachet Sous le Puits  Hierarchy_03
# 848                      IGP Pays d'Oc  Hierarchy_02
# 588                            Toscana  Hierarchy_01
# 653                        Paso Robles  Hierarchy_01
# 634                         Terra Alta  Hierarchy_01
# 841                         St.-Joseph  Hierarchy_02
# 486             Minervois La Livinière  Hierarchy_01
# 964                     Knights Valley  Hierarchy_02
#
#                                                 Address
# 642                                     Valencia, Spain
# 212                                               Italy
# 1029  Puligny-Montrachet, Côte de Beaune, Burgundy, ...
# 848             Pays d'Oc, Languedoc-Roussillon, France
# 588                                      Tuscany, Italy
# 653                                     California, USA
# 634                        Catalonia | Catalunya, Spain
# 841                           St.-Joseph, Rhône, France
# 486                        Languedoc-Roussillon, France
# 964                        North Coast, California, USA

# %%
df_GeoList.sample(10)
# Out:
#                                                Address
# 238  Minervois La Livinière, Minervois, Languedoc-R...
# 410        Vallagarina IGT, Trentino,Alto Adige, Italy
# 217                        Maconnais, Burgundy, France
# 376  St.-Aubin Premier Cru, St.-Aubin, Côte de Beau...
# 213                          Macedonia, Greece, Greece
# 68   Carneros, Napa Valley, Napa County, North Coas...
# 128                        Côtes du Jura, Jura, France
# 123                   Côte de Beaune, Burgundy, France
# 174                     Heathcote, Victoria, Australia
# 10                                      Alsace, France

# %% [markdown]
# ### Geocode the Address dataframe
# Reference: [Python’s geocoding — Convert a list of addresses into a map](https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6)

# %%
# Initialize Nominatim into geolocator variable.
geolocator = Nominatim(user_agent='wine app')

# %%
geolocator.geocode('Castilla y León, Spain').raw
# Out:
# {'place_id': 258252333,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 349041,
#  'boundingbox': ['40.0824504', '43.2382034', '-7.077073', '-1.7753716'],
#  'lat': '41.8037172',
#  'lon': '-4.7471726',
#  'display_name': 'Castilla y León, España',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.9625997816800999,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}

# %%
geolocator.geocode('Castilla y León, Spain').point
# Out:
# Point(41.8037172, -4.7471726, 0.0)

# %%
# Apply geolocator to the Address column in the GeoList dataframe.
df_GeoList['loc'] = df_GeoList['Address'].apply(geolocator.geocode)

# %%
# Get .point containing lat/long from Geocode response, if not none.
df_GeoList['point'] = df_GeoList['loc'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# Split the .point column into separate columns for lat, long, and altitude
df_GeoList[['lat', 'long', 'altitude']] = pd.DataFrame(df_GeoList['point'].to_list(), index=df_GeoList.index)

# %%
df_GeoList
# Out:
#                                                Address  \
# 0                                       Abruzzo, Italy
# 1           Adelaide Hills, South Australia, Australia
# 2                               Aegean Islands, Greece
# 3             Aglianico del Vulture, Basilicata, Italy
# 4                           Agrelo, Mendoza, Argentina
# 5                     Alba, Piedmont | Piemonte, Italy
# 6                                   Alentejo, Portugal
# 7    Alexander Valley, Sonoma County, North Coast, ...
# 8                            Alicante, Valencia, Spain
# 9                   Almansa, Castilla La Mancha, Spain
# 10                                      Alsace, France
# 11   Alto Adige Terlano, Alto Adige, Sudtirol, Tren...
# 12    Alto Adige, Sudtirol, Trentino-Alto Adige, Italy
# 13    Alto Adige, Sudtirol, Trentino,Alto Adige, Italy
# 14    Amador County, Sierra Foothills, California, USA
# 15           Amarone della Valpolicella, Veneto, Italy
# 16                 Amyndaio, Macedonia, Greece, Greece
# 17                                    Andalucia, Spain
# 18   Anderson Valley, Mendocino County, North Coast...
# 19                                Anjou, Loire, France
# 20                     Apalta, Colchagua Valley, Chile
# 21                            Apremont, Savoie, France
# 22                                       Aragon, Spain
# 23                       Arbois Pupillin, Jura, France
# 24                                           Argentina
# 25   Arroyo Grande Valley, San Luis Obispo County, ...
# 26                               Auckland, New Zealand
# 27                                           Australia
# 28                                             Austria
# 29                            Bandol, Provence, France
# ..                                                 ...
# 415                                        Var, France
# 416                          Veneto IGT, Veneto, Italy
# 417                                      Veneto, Italy
# 418     Verdicchio dei Castelli di Jesi, Marche, Italy
# 419              Verona IGT, Veneto IGT, Veneto, Italy
# 420                                Victoria, Australia
# 421  Vigneti delle Dolomiti IGT, Trentino,Alto Adig...
# 422                      Vin de Corse, Corsica, France
# 423       Vino Nobile di Montepulciano, Tuscany, Italy
# 424                           Vinsobres, Rhône, France
# 425           Volnay, Côte de Beaune, Burgundy, France
# 426  Vosne-Romanée Aux Brûlées, Vosne-Romanée Premi...
# 427  Vosne-Romanée Clos des Réas , Vosne-Romanée Pr...
# 428  Vosne-Romanée Cros Parantoux, Vosne-Romanée Pr...
# 429  Vosne-Romanée Les Beaux Monts, Vosne-Romanée P...
# 430  Vosne-Romanée Les Chaumes, Vosne-Romanée Premi...
# 431  Vosne-Romanée Premier Cru, Vosne-Romanée, Côte...
# 432     Vosne-Romanée, Côte de Nuits, Burgundy, France
# 433           Vougeot, Côte de Nuits, Burgundy, France
# 434                   Vouvray, Touraine, Loire, France
# 435                                    Wachau, Austria
# 436  Walker Bay, Cape South Coast, Western Cape, So...
# 437                Walla Walla Valley, Washington, USA
# 438                                    Washington, USA
# 439                       Western Australia, Australia
# 440                         Western Cape, South Africa
# 441                     Willamette Valley, Oregon, USA
# 442                     Yakima Valley, Washington, USA
# 443  Yamhill-Carlton District, Willamette Valley, O...
# 444                  Yarra Valley, Victoria, Australia
#
#                                                    loc  \
# 0            (Abruzzo, Italia, (42.227681, 13.854983))
# 1    (Adelaide Hills Council, South Australia, Aust...
# 2    (Aegean, Σάμη - Αγία Ευφημία, Καραβόμυλος, Δήμ...
# 3                                                 None
# 4    (Agrelo, Distrito Agrelo, Departamento Luján d...
# 5                                                 None
# 6       (Alentejo, Portugal, (38.0551003, -7.8605799))
# 7                                                 None
# 8    (Alacant / Alicante, l'Alacantí, Alacant / Ali...
# 9    (Almansa, Albacete, Castilla-La Mancha, 02640,...
# 10   (Alsace, France métropolitaine, France, (48.24...
# 11                                                None
# 12   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 13   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 14                                                None
# 15                                                None
# 16                                                None
# 17       (Andalucía, España, (37.3399964, -4.5811614))
# 18                                                None
# 19   (Anjoux, Sagy, Louhans, Saône-et-Loire, Bourgo...
# 20   (Viña Apalta, Millahue de Apalta, Santa Cruz, ...
# 21   (Apremont, Chambéry, Savoie, Auvergne-Rhône-Al...
# 22          (Aragón, España, (41.3787291, -0.7639373))
# 23                                                None
# 24             (Argentina, (-34.9964963, -64.9672817))
# 25                                                None
# 26   (Auckland, Waitematā, Auckland, 1010, New Zeal...
# 27                 (Australia, (-24.7761086, 134.755))
# 28               (Österreich, (47.2000338, 13.199959))
# 29   (Bandol, Toulon, Var, Provence-Alpes-Côte d'Az...
# ..                                                 ...
# 415  (Var, Provence-Alpes-Côte d'Azur, France métro...
# 416                                               None
# 417         (Veneto, Italia, (45.6476663, 11.8665254))
# 418                                               None
# 419                                               None
# 420  (Victoria, Australia, (-36.5986096, 144.6780052))
# 421                                               None
# 422  (Les Plaisirs du Vin, Rue du Général de Gaulle...
# 423                                               None
# 424  (Vinsobres, Nyons, Drôme, Auvergne-Rhône-Alpes...
# 425                                               None
# 426                                               None
# 427                                               None
# 428                                               None
# 429                                               None
# 430                                               None
# 431                                               None
# 432                                               None
# 433                                               None
# 434  (Rue de Vouvray, Auzouer-en-Touraine, Loches, ...
# 435  (Wachau, Bezirk Krems, Niederösterreich, Öster...
# 436                                               None
# 437  (Walla Walla, Walla Walla County, Washington, ...
# 438  (Washington, District of Columbia, United Stat...
# 439  (Western Australia, Australia, (-25.2303005, 1...
# 440  (Western Cape, South Africa, (-33.546977, 20.7...
# 441  (Willamette, West Linn, Metro, Oregon, 97068, ...
# 442  (Yakima, Yakima County, Washington, United Sta...
# 443                                               None
# 444  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
#
#                                              point        lat        long  \
# 0                      (42.227681, 13.854983, 0.0)  42.227681   13.854983
# 1    (-34.901351649999995, 138.8293202817461, 0.0) -34.901352  138.829320
# 2                    (38.2504094, 20.6304217, 0.0)  38.250409   20.630422
# 3                                             None        NaN         NaN
# 4                  (-33.1184629, -68.8859261, 0.0) -33.118463  -68.885926
# 5                                             None        NaN         NaN
# 6                    (38.0551003, -7.8605799, 0.0)  38.055100   -7.860580
# 7                                             None        NaN         NaN
# 8                     (38.353738, -0.4901846, 0.0)  38.353738   -0.490185
# 9                    (38.8682065, -1.0978627, 0.0)  38.868206   -1.097863
# 10             (48.24917645, 7.4074699518555, 0.0)  48.249176    7.407470
# 11                                            None        NaN         NaN
# 12          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 13          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 14                                            None        NaN         NaN
# 15                                            None        NaN         NaN
# 16                                            None        NaN         NaN
# 17                   (37.3399964, -4.5811614, 0.0)  37.339996   -4.581161
# 18                                            None        NaN         NaN
# 19                     (46.564187, 5.3193257, 0.0)  46.564187    5.319326
# 20                 (-34.6239248, -71.2671251, 0.0) -34.623925  -71.267125
# 21                         (45.5132, 5.95937, 0.0)  45.513200    5.959370
# 22                   (41.3787291, -0.7639373, 0.0)  41.378729   -0.763937
# 23                                            None        NaN         NaN
# 24                 (-34.9964963, -64.9672817, 0.0) -34.996496  -64.967282
# 25                                            None        NaN         NaN
# 26                  (-36.852095, 174.7631803, 0.0) -36.852095  174.763180
# 27                     (-24.7761086, 134.755, 0.0) -24.776109  134.755000
# 28                    (47.2000338, 13.199959, 0.0)  47.200034   13.199959
# 29                    (43.1357717, 5.7523647, 0.0)  43.135772    5.752365
# ..                                             ...        ...         ...
# 415             (43.4173592, 6.2664620128919, 0.0)  43.417359    6.266462
# 416                                           None        NaN         NaN
# 417                  (45.6476663, 11.8665254, 0.0)  45.647666   11.866525
# 418                                           None        NaN         NaN
# 419                                           None        NaN         NaN
# 420                (-36.5986096, 144.6780052, 0.0) -36.598610  144.678005
# 421                                           None        NaN         NaN
# 422                   (41.5903081, 9.2780396, 0.0)  41.590308    9.278040
# 423                                           None        NaN         NaN
# 424                   (44.3339938, 5.0609674, 0.0)  44.333994    5.060967
# 425                                           None        NaN         NaN
# 426                                           None        NaN         NaN
# 427                                           None        NaN         NaN
# 428                                           None        NaN         NaN
# 429                                           None        NaN         NaN
# 430                                           None        NaN         NaN
# 431                                           None        NaN         NaN
# 432                                           None        NaN         NaN
# 433                                           None        NaN         NaN
# 434                   (47.5835908, 0.9204818, 0.0)  47.583591    0.920482
# 435           (48.3275563, 15.41162578949626, 0.0)  48.327556   15.411626
# 436                                           None        NaN         NaN
# 437                (46.0667277, -118.3393456, 0.0)  46.066728 -118.339346
# 438                 (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558
# 439                (-25.2303005, 121.0187246, 0.0) -25.230300  121.018725
# 440                    (-33.546977, 20.72753, 0.0) -33.546977   20.727530
# 441                (45.3442868, -122.6670374, 0.0)  45.344287 -122.667037
# 442                 (46.601557, -120.5108421, 0.0)  46.601557 -120.510842
# 443                                           None        NaN         NaN
# 444                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
#
#      altitude
# 0         0.0
# 1         0.0
# 2         0.0
# 3         NaN
# 4         0.0
# 5         NaN
# 6         0.0
# 7         NaN
# 8         0.0
# 9         0.0
# 10        0.0
# 11        NaN
# 12        0.0
# 13        0.0
# 14        NaN
# 15        NaN
# 16        NaN
# 17        0.0
# 18        NaN
# 19        0.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        NaN
# 24        0.0
# 25        NaN
# 26        0.0
# 27        0.0
# 28        0.0
# 29        0.0
# ..        ...
# 415       0.0
# 416       NaN
# 417       0.0
# 418       NaN
# 419       NaN
# 420       0.0
# 421       NaN
# 422       0.0
# 423       NaN
# 424       0.0
# 425       NaN
# 426       NaN
# 427       NaN
# 428       NaN
# 429       NaN
# 430       NaN
# 431       NaN
# 432       NaN
# 433       NaN
# 434       0.0
# 435       0.0
# 436       NaN
# 437       0.0
# 438       0.0
# 439       0.0
# 440       0.0
# 441       0.0
# 442       0.0
# 443       NaN
# 444       0.0
#
# [445 rows x 6 columns]

# %% [markdown]
# ### Append geography details to the GeoCache dataframe
# Determine how well populated geography is at different hierarchy levels.

# %%
df_GeoCache = pd.merge(df_GeoCache, df_GeoList, on = 'Address', how = 'left' )

# %%
df_GeoCache.to_csv(path_or_buf = './GeoCache.csv', index = False)

# %% [markdown]
# ### Append Hierarchy 00 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache00 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_00')
]

df_GeoCache00.sample(10)
# Out:
#                         Geography     Hierarchy    Address  \
# 304                          Lodi  Hierarchy_00        USA
# 223        Brunello di Montalcino  Hierarchy_00      Italy
# 112                    Richebourg  Hierarchy_00     France
# 145           Châteauneuf-du-Pape  Hierarchy_00     France
# 116  Vosne-Romanée Cros Parantoux  Hierarchy_00     France
# 70           Crémant de Bourgogne  Hierarchy_00     France
# 22                South Australia  Hierarchy_00  Australia
# 198                  Rosso Piceno  Hierarchy_00      Italy
# 102                     Echézeaux  Hierarchy_00     France
# 170                      Rheingau  Hierarchy_00    Germany
#
#                                              loc  \
# 304  (United States, (39.7837304, -100.4458825))
# 223            (Italia, (42.6384261, 12.674297))
# 112             (France, (46.603354, 1.8883335))
# 145             (France, (46.603354, 1.8883335))
# 116             (France, (46.603354, 1.8883335))
# 70              (France, (46.603354, 1.8883335))
# 22           (Australia, (-24.7761086, 134.755))
# 198            (Italia, (42.6384261, 12.674297))
# 102             (France, (46.603354, 1.8883335))
# 170      (Deutschland, (51.0834196, 10.4234469))
#
#                                point        lat        long  altitude
# 304  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882       0.0
# 223     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 112      (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 145      (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 116      (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 70       (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 22       (-24.7761086, 134.755, 0.0) -24.776109  134.755000       0.0
# 198     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 102      (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 170    (51.0834196, 10.4234469, 0.0)  51.083420   10.423447       0.0

# %%
df_Wine00 = pd.merge(df_Wine, df_GeoCache00, on = 'Geography', how = 'left')

df_Wine00.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price                   Winemaker  \
# 2080       2000.0   79    1998   90.0    12              Columbia Crest
# 409        2016.0    9    2013   96.0   106  Château Smith-Haut-Lafitte
# 922        2011.0   21    2009   93.0    15             Georges Duboeuf
# 41         2020.0   42    2013   93.0    40               Gloria Ferrer
# 338        2017.0   39    2014   94.0    50               Spring Valley
# 2147       1999.0   46    1995   92.0    30              Giovanni Sordo
# 1070       2010.0   69    2008   91.0    28                  Orin Swift
# 709        2013.0    8    2010   96.0   120       Château de Beaucastel
# 92         2020.0   93    2017   97.0   127       Château Pavie-Decesse
# 1297       2008.0   96    2006   93.0    60                      Cabreo
#
#                                            Wine Wine_Style  \
# 2080   Chardonnay Columbia Valley Estate Series      White
# 409                        Pessac-Léognan White      White
# 922                       Morgon Jean Descombes        Red
# 41    Brut Carneros Royal Cuvée Late Disgorged   Sparkling
# 338                Frederick Walla Walla Valley        Red
# 2147                                     Barolo        Red
# 1070                 Zinfandel California Saldo        Red
# 709                         Châteauneuf-du-Pape        Red
# 92                                 St.-Emilion         Red
# 1297                           Toscana Il Borgo        Red
#
#               Grape_Blend                                         Blend_List  \
# 2080          Chardonnay                                                 NaN
# 409                 Blend      Sauvignon Blanc, Sauvignon Gris and Sémillon
# 922                 Gamay                                                NaN
# 41                  Blend                                    Sparkling Blend
# 338                 Blend  Cabernet Sauvignon, Cabernet Franc, Merlot, Pe...
# 2147                Blend                                           Nebbiolo
# 1070            Zinfandel                                                NaN
# 709   Châteauneuf-du-Pape                                                NaN
# 92                  Blend                        Merlot and Cabernet Franc
# 1297                Blend                 Sangiovese and Cabernet Sauvignon
#
#       ... Best_Drink_from  Best_Drink_Through  \
# 2080  ...          2000.0              2003.0
# 409   ...          2017.0              2023.0
# 922   ...          2011.0                 NaN
# 41    ...          2020.0                 NaN
# 338   ...          2017.0              2023.0
# 2147  ...          1999.0              2007.0
# 1070  ...          2010.0              2015.0
# 709   ...          2016.0              2035.0
# 92    ...          2022.0              2040.0
# 1297  ...          2011.0                 NaN
#
#                                                  Review     Hierarchy  \
# 2080  A complex, creamy Washington white, rich, long...  Hierarchy_00
# 409   This has a gorgeous feel, with opulent fruit o...  Hierarchy_00
# 922   Light tannins and a smoky mineral note frame t...  Hierarchy_00
# 41    A sumptuous and rich style, with vibrant Asian...  Hierarchy_00
# 338   Refined and impeccably structured, with floral...  Hierarchy_00
# 2147  Delicate and pure, with gorgeous balance. Ligh...  Hierarchy_00
# 1070  Well-built, yet rich and stylish, with spicy b...  Hierarchy_00
# 709   Dark, dense and very closed now, this has a tr...  Hierarchy_00
# 92    This is laden with cassis and warmed plum comp...  Hierarchy_00
# 1297  This is dark and rich, with loads of blackberr...  Hierarchy_00
#
#       Address                                          loc  \
# 2080      USA  (United States, (39.7837304, -100.4458825))
# 409    France             (France, (46.603354, 1.8883335))
# 922    France             (France, (46.603354, 1.8883335))
# 41        USA  (United States, (39.7837304, -100.4458825))
# 338       USA  (United States, (39.7837304, -100.4458825))
# 2147    Italy            (Italia, (42.6384261, 12.674297))
# 1070      USA  (United States, (39.7837304, -100.4458825))
# 709    France             (France, (46.603354, 1.8883335))
# 92     France             (France, (46.603354, 1.8883335))
# 1297    Italy            (Italia, (42.6384261, 12.674297))
#
#                                 point        lat        long altitude
# 2080  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 409       (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 922       (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 41    (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 338   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 2147     (42.6384261, 12.674297, 0.0)  42.638426   12.674297      0.0
# 1070  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 709       (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 92        (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 1297     (42.6384261, 12.674297, 0.0)  42.638426   12.674297      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Append Hierarchy 01 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache01 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_01')
]

df_GeoCache01.sample(10)
# Out:
#                        Geography     Hierarchy  \
# 444                Le Montrachet  Hierarchy_01
# 365                Hunter Valley  Hierarchy_01
# 435          Corton Les Renardes  Hierarchy_01
# 629                         Toro  Hierarchy_01
# 572                         Etna  Hierarchy_01
# 355  Cafayate - Calchaqui Valley  Hierarchy_01
# 522                        Mosel  Hierarchy_01
# 455                      Musigny  Hierarchy_01
# 614                   Constantia  Hierarchy_01
# 485                    Languedoc  Hierarchy_01
#
#                                     Address  \
# 444                        Burgundy, France
# 365              New South Wales, Australia
# 435                        Burgundy, France
# 629                  Castilla y León, Spain
# 572                           Sicily, Italy
# 355  Cafayate , Calchaqui Valley, Argentina
# 522                          Mosel, Germany
# 455                        Burgundy, France
# 614              Western Cape, South Africa
# 485            Languedoc-Roussillon, France
#
#                                                    loc  \
# 444  (Bourgogne, France métropolitaine, France, (47...
# 365  (New South Wales, Australia, (-31.8759835, 147...
# 435  (Bourgogne, France métropolitaine, France, (47...
# 629  (Castilla y León, España, (41.8037172, -4.7471...
# 572          (Sicilia, Italia, (37.587794, 14.155048))
# 355  (Calchaquí, Municipio de Animaná, Cafayate, Sa...
# 522  (Mosel, Lützel, Koblenz, Rheinland-Pfalz, 5607...
# 455  (Bourgogne, France métropolitaine, France, (47...
# 614  (Western Cape, South Africa, (-33.546977, 20.7...
# 485  (Languedoc-Roussillon, France métropolitaine, ...
#
#                                      point        lat        long  altitude
# 444  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 365        (-31.8759835, 147.2869493, 0.0) -31.875984  147.286949       0.0
# 435  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 629          (41.8037172, -4.7471726, 0.0)  41.803717   -4.747173       0.0
# 572            (37.587794, 14.155048, 0.0)  37.587794   14.155048       0.0
# 355        (-26.0051871, -65.8669424, 0.0) -26.005187  -65.866942       0.0
# 522           (50.3659752, 7.5858251, 0.0)  50.365975    7.585825       0.0
# 455  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 614            (-33.546977, 20.72753, 0.0) -33.546977   20.727530       0.0
# 485  (43.65420305, 3.674669940206605, 0.0)  43.654203    3.674670       0.0

# %%
df_Wine01 = pd.merge(df_Wine, df_GeoCache01, on = 'Geography', how = 'left')

df_Wine01.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price              Winemaker  \
# 2149       1999.0   48    1997   94.0    52       J. Moreau & Fils
# 1290       2008.0   89    2006   90.0    18            Stadt Krems
# 2868       1992.0   66    1990   88.0    28            Kumeu River
# 2354       1997.0   53    1995   92.0    15          Flora Springs
# 981        2011.0   80    2008   96.0   150              Continuum
# 1872       2002.0   71    2000   90.0    24                 Talley
# 1685       2004.0   84    2003   90.0    13             Waterbrook
# 3070       1990.0   68    1988   91.0    20             Saintsbury
# 2587       1995.0   86    1993   90.0    25  Chateau Ste. Michelle
# 436        2016.0   36    2011   95.0    70             G.D. Vajra
#
#                                                    Wine Wine_Style  \
# 2149                                   Chablis Les Clos      White
# 1290  Grüner Veltliner Qualitätswein Trocken Kremsta...      White
# 2868                                   Chardonnay Kumeu      White
# 2354                             Sangiovese Napa Valley        Red
# 981                                         Napa Valley        Red
# 1872                    Chardonnay Arroyo Grande Valley      White
# 1685                            Mélange Columbia Valley        Red
# 3070                                Pinot Noir Carneros        Red
# 2587     Chardonnay Columbia Valley Cold Creek Vineyard      White
# 436                           Barolo Bricco delle Viole        Red
#
#       Grape_Blend                                         Blend_List  ...  \
# 2149  Chardonnay                                                 NaN  ...
# 1290       Grüner                                                NaN  ...
# 2868  Chardonnay                                                 NaN  ...
# 2354   Sangiovese                                                NaN  ...
# 981         Blend  Cabernet Sauvignon, Cabernet Franc, Petit Verd...  ...
# 1872  Chardonnay                                                 NaN  ...
# 1685        Blend  Cabernet Sauvignon, Sangiovese, Merlot, Syrah ...  ...
# 3070   Pinot Noir                                                NaN  ...
# 2587  Chardonnay                                                 NaN  ...
# 436         Blend                                           Nebbiolo  ...
#
#      Best_Drink_from  Best_Drink_Through  \
# 2149          2003.0              2015.0
# 1290          2008.0              2015.0
# 2868             NaN                 NaN
# 2354             NaN                 NaN
# 981           2013.0              2023.0
# 1872          2002.0              2005.0
# 1685          2004.0              2010.0
# 3070          1990.0                 NaN
# 2587          1995.0              1997.0
# 436           2019.0              2032.0
#
#                                                  Review     Hierarchy  \
# 2149  Incredibly fresh and vibrant in style, the cha...  Hierarchy_01
# 1290  Intense, with concentrated flavors of ripe pea...  Hierarchy_01
# 2868  Pulls out all the stops. Ripe, buttery aromas ...  Hierarchy_01
# 2354  Openly fruity, with lots of ripe blackberry an...  Hierarchy_01
# 981   A remarkable effort, offering riveting, expres...  Hierarchy_01
# 1872  A wine of finesse and elegance, with intense, ...  Hierarchy_01
# 1685  Ripe and plump, generous with its spicy, mocha...  Hierarchy_01
# 3070  Difficult to find a better Pinot Noir at this ...  Hierarchy_01
# 2587  Subtle, harmonious and beautifully balanced, b...  Hierarchy_01
# 436   Graphite and iron aromas lead off, with cherry...  Hierarchy_01
#
#                          Address  \
# 2149            Burgundy, France
# 1290           Kremstal, Austria
# 2868       Auckland, New Zealand
# 2354             California, USA
# 981              California, USA
# 1872             California, USA
# 1685             Washington, USA
# 3070             California, USA
# 2587             Washington, USA
# 436   Piedmont | Piemonte, Italy
#
#                                                     loc  \
# 2149  (Bourgogne, France métropolitaine, France, (47...
# 1290  (Inzersdorf im Kremstal, Bezirk Kirchdorf, Obe...
# 2868  (Auckland, Waitematā, Auckland, 1010, New Zeal...
# 2354  (California, United States, (36.7014631, -118....
# 981   (California, United States, (36.7014631, -118....
# 1872  (California, United States, (36.7014631, -118....
# 1685  (Washington, District of Columbia, United Stat...
# 3070  (California, United States, (36.7014631, -118....
# 2587  (Washington, District of Columbia, United Stat...
# 436   (Piedmont Properties, 78, SP50, San Marzano Ol...
#
#                                       point        lat        long altitude
# 2149  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486      0.0
# 1290          (47.9263917, 14.0780469, 0.0)  47.926392   14.078047      0.0
# 2868         (-36.852095, 174.7631803, 0.0) -36.852095  174.763180      0.0
# 2354         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 981          (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 1872         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 1685         (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558      0.0
# 3070         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 2587         (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558      0.0
# 436            (44.7605629, 8.2998538, 0.0)  44.760563    8.299854      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Save files for use in other notebooks

# %%
# Remove duplicates by index: 2017 (46), 2015 (73), 1995 (94)
df_Wine00 = df_Wine00.drop([df_Wine00.index[2596], df_Wine00.index[574], df_Wine00.index[346]])
df_Wine01 = df_Wine01.drop([df_Wine00.index[2596], df_Wine00.index[574], df_Wine00.index[346]])

# %%
df_Wine00.shape
# Out:
# (3301, 25)

# %%
df_Wine01.shape
# Out:
# (3301, 25)

# %%
df_Wine00.to_csv(path_or_buf = './Wine_Hier00.csv', index = False)
df_Wine01.to_csv(path_or_buf = './Wine_Hier01.csv', index = False)
