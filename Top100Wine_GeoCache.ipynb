# %% [markdown]
# # GeoCache: *Wine Spectator*'s Top 100 Wines, 1988-2020
# List available online on *Wine Spectator*'s [Top 100 Lists web site](https://top100.winespectator.com/lists/).

# %% [markdown]
# ## File Setup

# %%
# import and initialize main python libraries
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# import libraries for file navigation
import os
import shutil
import glob
from pandas_ods_reader import read_ods

# import other packages
from scipy import stats
from sklearn import linear_model

# import geo packages
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon

# import Geopy packages
import geopy
from geopy.geocoders import Nominatim

# %%
# initialize vizualization set
sns.set(style="whitegrid", palette="colorblind", color_codes=True)
sns.mpl.rc("figure", figsize=(10, 6))

# Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Dataframe Exploration

# %%
# Note: save CSV files in UTF-8 format to preserve special characters.
df_Wine = pd.read_csv('./CSV_Wines.csv')
df_GeoCache = pd.read_csv('./CSV_GeoCache.csv')
df_GeoList = pd.read_csv('./CSV_GeoList.csv')

# %%
df_Wine.shape
# Out:
# (3301, 18)

# %%
df_Wine.dtypes
# Out:
# Review_Year           float64
# Rank                   object
# Vintage                object
# Score                 float64
# Price                  object
# Winemaker              object
# Wine                   object
# Wine_Style             object
# Grape_Blend            object
# Blend_List             object
# Geography              object
# Cases_Made            float64
# Cases_Imported        float64
# Reviewer               object
# Drink_now             float64
# Best_Drink_from       float64
# Best_Drink_Through    float64
# Review                 object
# dtype: object

# %%
df_GeoCache.shape
# Out:
# (1226, 3)

# %%
df_GeoList.shape
# Out:
# (448, 1)

# %%
df_Wine.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price                  Winemaker  \
# 81         2020.0   82    2016   90.0    20                Tormaresca
# 2449       1996.0   50    1994   93.0    40       Michel Colin-Deléger
# 2622       1994.0   23      NV   93.0    30            Piper-Heidsieck
# 3038       1990.0   39    1988   90.0     8                  Rosemount
# 416        2016.0   17    2014   93.0    32              Merry Edwards
# 35         2020.0   36    2015   92.0    24  Marchesi de' Frescobaldi
# 412        2016.0   13    2013   97.0    70                   Reynvaan
# 212        2018.0   13    2013   96.0    66  Produttori del Barbaresco
# 842        2012.0   43    2010   91.0    18    Château de la Greffière
# 2706       1993.0    7    1990   94.0    15               Mount Veeder
#
#                                         Wine Wine_Style          Grape_Blend  \
# 81              Primitivo Salento Torcicoda         Red            Primitivo
# 2449         Chassagne-Montrachet En Remilly      White          Chardonnay
# 2622                     Brut Rosé Champagne  Sparkling            Champagne
# 3038                    Shiraz Hunter Valley        Red       Shiraz | Syrah
# 416     Sauvignon Blanc Russian River Valley      White      Sauvignon Blanc
# 35           Chianti Classico Tenuta Perano         Red              Chianti
# 412    Syrah Walla Walla Valley In The Rocks        Red       Shiraz | Syrah
# 212                Barbaresco Rabajà Riserva        Red                Blend
# 842   Mâcon-La Roche Vineuse Vieilles Vignes      White          Chardonnay
# 2706          Cabernet Sauvignon Napa Valley        Red  Cabernet Sauvignon
#
#      Blend_List                        Geography  Cases_Made  Cases_Imported  \
# 81          NaN                      Salento IGT         NaN          4000.0
# 2449        NaN  Chassagne-Montrachet En Remilly       408.0             NaN
# 2622        NaN                        Champagne      9000.0             NaN
# 3038        NaN                    Hunter Valley      6000.0             NaN
# 416         NaN             Russian River Valley      9500.0             NaN
# 35          NaN                          Chianti         NaN          2000.0
# 412         NaN               Walla Walla Valley       602.0             NaN
# 212    Nebbiolo                       Barbaresco      1420.0             NaN
# 842         NaN           Mâcon-La Roche Vineuse         NaN          2000.0
# 2706        NaN                      Napa Valley      2400.0             NaN
#
#      Reviewer  Drink_now  Best_Drink_from  Best_Drink_Through  \
# 81         AN        1.0           2020.0              2025.0
# 2449      NaN        NaN           1999.0                 NaN
# 2622      NaN        NaN              NaN                 NaN
# 3038      NaN        NaN           1993.0                 NaN
# 416        MW        1.0           2016.0                 NaN
# 35         BS        NaN           2021.0              2033.0
# 412        HS        1.0           2016.0              2025.0
# 212        BS        NaN           2023.0              2038.0
# 842        BS        1.0           2012.0              2016.0
# 2706      NaN        NaN              NaN                 NaN
#
#                                                  Review
# 81    Well-balanced and fresh, this medium-bodied re...
# 2449  Seductive and charming, boasting tons of ripe ...
# 2622  Has the taste of authenticity, with a provocat...
# 3038  An outstanding red wine. Very ripe and rich, w...
# 416   Succulent, lush and rich, with fleshy mango, m...
# 35    The core black cherry and blackberry flavors a...
# 412   Supple and expressive, this opens up like a gi...
# 212   This fruity version features floral, cherry an...
# 842   A light oak influence adds roundness and a hin...
# 2706  Opulent and chewy with lots of ripe fruit flav...

# %%
df_GeoCache.sample(10)
# Out:
#                              Geography     Hierarchy  \
# 966                      Sonoma County  Hierarchy_02
# 186                      Greco di Tufo  Hierarchy_00
# 1205  Puligny-Montrachet Les Combettes  Hierarchy_05
# 823                          Montlouis  Hierarchy_02
# 249                         Hawkes Bay  Hierarchy_00
# 218                 Alto Adige Terlano  Hierarchy_00
# 970               Santa Cruz Mountains  Hierarchy_02
# 1199      Chassagne-Montrachet Morgeot  Hierarchy_05
# 388                           Kremstal  Hierarchy_01
# 514                         Vacqueyras  Hierarchy_01
#
#                                                 Address
# 966                        North Coast, California, USA
# 186                                               Italy
# 1205  Puligny-Montrachet Les Combettes, Puligny-Mont...
# 823                             Touraine, Loire, France
# 249                                         New Zealand
# 218                                               Italy
# 970    San Francisco Bay, California Central Coast, USA
# 1199  Chassagne-Montrachet Morgeot, Chassagne-Montra...
# 388                                   Kremstal, Austria
# 514                                       Rhône, France

# %%
df_GeoList.sample(10)
# Out:
#                                                Address
# 92   Chehalem Mountains, Willamette Valley, Oregon,...
# 266                                    New Mexico, USA
# 363                                     Sicilia, Italy
# 140                                    Douro, Portugal
# 254           Moulis-en-Médoc, Médoc, Bordeaux, France
# 3             Aglianico del Vulture, Basilicata, Italy
# 144   Eden Valley, Barossa, South Australia, Australia
# 172                Haut-Médoc, Médoc, Bordeaux, France
# 253                  Moulin-à-Vent, Beaujolais, France
# 328                                       Rioja, Spain

# %% [markdown]
# ### Geocode the Address dataframe
# Reference: [Python’s geocoding — Convert a list of addresses into a map](https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6)

# %%
# Initialize Nominatim into geolocator variable.
geolocator = Nominatim(user_agent='wine app')

# %%
geolocator.geocode('Castilla y León, Spain').raw
# Out:
# {'place_id': 258252333,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 349041,
#  'boundingbox': ['40.0824504', '43.2382034', '-7.077073', '-1.7753716'],
#  'lat': '41.8037172',
#  'lon': '-4.7471726',
#  'display_name': 'Castilla y León, España',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.9625997816800999,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}

# %%
geolocator.geocode('Castilla y León, Spain').point
# Out:
# Point(41.8037172, -4.7471726, 0.0)

# %%
# Apply geolocator to the Address column in the GeoList dataframe.
df_GeoList['loc'] = df_GeoList['Address'].apply(geolocator.geocode)

# %%
# Get .point containing lat/long from Geocode response, if not none.
df_GeoList['point'] = df_GeoList['loc'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# Split the .point column into separate columns for lat, long, and altitude
df_GeoList[['lat', 'long', 'altitude']] = pd.DataFrame(df_GeoList['point'].to_list(), index=df_GeoList.index)

# %%
df_GeoList
# Out:
#                                                Address  \
# 0                                       Abruzzo, Italy
# 1           Adelaide Hills, South Australia, Australia
# 2                               Aegean Islands, Greece
# 3             Aglianico del Vulture, Basilicata, Italy
# 4                           Agrelo, Mendoza, Argentina
# 5                     Alba, Piedmont | Piemonte, Italy
# 6                                   Alentejo, Portugal
# 7    Alexander Valley, Sonoma County, North Coast, ...
# 8                            Alicante, Valencia, Spain
# 9                   Almansa, Castilla La Mancha, Spain
# 10                                      Alsace, France
# 11   Alto Adige Terlano, Alto Adige, Sudtirol, Tren...
# 12    Alto Adige, Sudtirol, Trentino-Alto Adige, Italy
# 13    Alto Adige, Sudtirol, Trentino,Alto Adige, Italy
# 14    Amador County, Sierra Foothills, California, USA
# 15           Amarone della Valpolicella, Veneto, Italy
# 16                 Amyndaio, Macedonia, Greece, Greece
# 17                                    Andalucia, Spain
# 18   Anderson Valley, Mendocino County, North Coast...
# 19                                Anjou, Loire, France
# 20                     Apalta, Colchagua Valley, Chile
# 21                            Apremont, Savoie, France
# 22                                       Aragon, Spain
# 23                       Arbois Pupillin, Jura, France
# 24                                           Argentina
# 25   Arroyo Grande Valley, San Luis Obispo County, ...
# 26                               Auckland, New Zealand
# 27                                           Australia
# 28                                             Austria
# 29                            Bandol, Provence, France
# ..                                                 ...
# 418     Verdicchio dei Castelli di Jesi, Marche, Italy
# 419              Verona IGT, Veneto IGT, Veneto, Italy
# 420                                Victoria, Australia
# 421  Vigneti delle Dolomiti IGT, Trentino,Alto Adig...
# 422                      Vin de Corse, Corsica, France
# 423                               Vin de Pays , France
# 424       Vino Nobile di Montepulciano, Tuscany, Italy
# 425                           Vinsobres, Rhône, France
# 426           Volnay, Côte de Beaune, Burgundy, France
# 427  Vosne-Romanée Aux Brûlées, Vosne-Romanée Premi...
# 428  Vosne-Romanée Clos des Réas , Vosne-Romanée Pr...
# 429  Vosne-Romanée Cros Parantoux, Vosne-Romanée Pr...
# 430  Vosne-Romanée Les Beaux Monts, Vosne-Romanée P...
# 431  Vosne-Romanée Les Chaumes, Vosne-Romanée Premi...
# 432  Vosne-Romanée Premier Cru, Vosne-Romanée, Côte...
# 433     Vosne-Romanée, Côte de Nuits, Burgundy, France
# 434           Vougeot, Côte de Nuits, Burgundy, France
# 435                   Vouvray, Touraine, Loire, France
# 436                                    Wachau, Austria
# 437  Walker Bay, Cape South Coast, Western Cape, So...
# 438                Walla Walla Valley, Washington, USA
# 439                                    Washington, USA
# 440                       Western Australia, Australia
# 441                         Western Cape, South Africa
# 442                     Willamette Valley, Oregon, USA
# 443                     Yakima Valley, Washington, USA
# 444  Yamhill-Carlton District, Willamette Valley, O...
# 445                  Yarra Valley, Victoria, Australia
# 446  Yamhill-Carlton District, Willamette Valley, O...
# 447                  Yarra Valley, Victoria, Australia
#
#                                                    loc  \
# 0            (Abruzzo, Italia, (42.227681, 13.854983))
# 1    (Adelaide Hills Council, South Australia, Aust...
# 2    (Aegean, Σάμη - Αγία Ευφημία, Καραβόμυλος, Δήμ...
# 3                                                 None
# 4    (Agrelo, Distrito Agrelo, Departamento Luján d...
# 5                                                 None
# 6       (Alentejo, Portugal, (38.0551003, -7.8605799))
# 7                                                 None
# 8    (Alacant / Alicante, l'Alacantí, Alacant / Ali...
# 9    (Almansa, Albacete, Castilla-La Mancha, 02640,...
# 10   (Alsace, France métropolitaine, France, (48.24...
# 11                                                None
# 12   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 13   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 14                                                None
# 15                                                None
# 16                                                None
# 17       (Andalucía, España, (37.3399964, -4.5811614))
# 18                                                None
# 19   (Anjoux, Sagy, Louhans, Saône-et-Loire, Bourgo...
# 20   (Viña Apalta, Millahue de Apalta, Santa Cruz, ...
# 21   (Apremont, Chambéry, Savoie, Auvergne-Rhône-Al...
# 22          (Aragón, España, (41.3787291, -0.7639373))
# 23                                                None
# 24             (Argentina, (-34.9964963, -64.9672817))
# 25                                                None
# 26   (Auckland, Waitematā, Auckland, 1010, New Zeal...
# 27                 (Australia, (-24.7761086, 134.755))
# 28               (Österreich, (47.2000338, 13.199959))
# 29   (Bandol, Toulon, Var, Provence-Alpes-Côte d'Az...
# ..                                                 ...
# 418                                               None
# 419                                               None
# 420  (Victoria, Australia, (-36.5986096, 144.6780052))
# 421                                               None
# 422  (Les Plaisirs du Vin, Rue du Général de Gaulle...
# 423  (Le Bois Vien, Craon, Château-Gontier, Mayenne...
# 424                                               None
# 425  (Vinsobres, Nyons, Drôme, Auvergne-Rhône-Alpes...
# 426                                               None
# 427                                               None
# 428                                               None
# 429                                               None
# 430                                               None
# 431                                               None
# 432                                               None
# 433                                               None
# 434                                               None
# 435  (Rue de Vouvray, Auzouer-en-Touraine, Loches, ...
# 436  (Wachau, Bezirk Krems, Niederösterreich, Öster...
# 437                                               None
# 438  (Walla Walla, Walla Walla County, Washington, ...
# 439  (Washington, District of Columbia, United Stat...
# 440  (Western Australia, Australia, (-25.2303005, 1...
# 441  (Western Cape, South Africa, (-33.546977, 20.7...
# 442  (Willamette, West Linn, Metro, Oregon, 97068, ...
# 443  (Yakima, Yakima County, Washington, United Sta...
# 444                                               None
# 445  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
# 446                                               None
# 447  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
#
#                                              point        lat        long  \
# 0                      (42.227681, 13.854983, 0.0)  42.227681   13.854983
# 1    (-34.901351649999995, 138.8293202817461, 0.0) -34.901352  138.829320
# 2                    (38.2504094, 20.6304217, 0.0)  38.250409   20.630422
# 3                                             None        NaN         NaN
# 4                  (-33.1184629, -68.8859261, 0.0) -33.118463  -68.885926
# 5                                             None        NaN         NaN
# 6                    (38.0551003, -7.8605799, 0.0)  38.055100   -7.860580
# 7                                             None        NaN         NaN
# 8                     (38.353738, -0.4901846, 0.0)  38.353738   -0.490185
# 9                    (38.8682065, -1.0978627, 0.0)  38.868206   -1.097863
# 10             (48.24917645, 7.4074699518555, 0.0)  48.249176    7.407470
# 11                                            None        NaN         NaN
# 12          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 13          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 14                                            None        NaN         NaN
# 15                                            None        NaN         NaN
# 16                                            None        NaN         NaN
# 17                   (37.3399964, -4.5811614, 0.0)  37.339996   -4.581161
# 18                                            None        NaN         NaN
# 19                     (46.564187, 5.3193257, 0.0)  46.564187    5.319326
# 20                 (-34.6239248, -71.2671251, 0.0) -34.623925  -71.267125
# 21                         (45.5132, 5.95937, 0.0)  45.513200    5.959370
# 22                   (41.3787291, -0.7639373, 0.0)  41.378729   -0.763937
# 23                                            None        NaN         NaN
# 24                 (-34.9964963, -64.9672817, 0.0) -34.996496  -64.967282
# 25                                            None        NaN         NaN
# 26                  (-36.852095, 174.7631803, 0.0) -36.852095  174.763180
# 27                     (-24.7761086, 134.755, 0.0) -24.776109  134.755000
# 28                    (47.2000338, 13.199959, 0.0)  47.200034   13.199959
# 29                    (43.1357717, 5.7523647, 0.0)  43.135772    5.752365
# ..                                             ...        ...         ...
# 418                                           None        NaN         NaN
# 419                                           None        NaN         NaN
# 420                (-36.5986096, 144.6780052, 0.0) -36.598610  144.678005
# 421                                           None        NaN         NaN
# 422                   (41.5903081, 9.2780396, 0.0)  41.590308    9.278040
# 423                  (47.8653429, -0.9011409, 0.0)  47.865343   -0.901141
# 424                                           None        NaN         NaN
# 425                   (44.3339938, 5.0609674, 0.0)  44.333994    5.060967
# 426                                           None        NaN         NaN
# 427                                           None        NaN         NaN
# 428                                           None        NaN         NaN
# 429                                           None        NaN         NaN
# 430                                           None        NaN         NaN
# 431                                           None        NaN         NaN
# 432                                           None        NaN         NaN
# 433                                           None        NaN         NaN
# 434                                           None        NaN         NaN
# 435                   (47.5835908, 0.9204818, 0.0)  47.583591    0.920482
# 436           (48.3275563, 15.41162578949626, 0.0)  48.327556   15.411626
# 437                                           None        NaN         NaN
# 438                (46.0667277, -118.3393456, 0.0)  46.066728 -118.339346
# 439                 (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558
# 440                (-25.2303005, 121.0187246, 0.0) -25.230300  121.018725
# 441                    (-33.546977, 20.72753, 0.0) -33.546977   20.727530
# 442                (45.3442868, -122.6670374, 0.0)  45.344287 -122.667037
# 443                 (46.601557, -120.5108421, 0.0)  46.601557 -120.510842
# 444                                           None        NaN         NaN
# 445                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
# 446                                           None        NaN         NaN
# 447                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
#
#      altitude
# 0         0.0
# 1         0.0
# 2         0.0
# 3         NaN
# 4         0.0
# 5         NaN
# 6         0.0
# 7         NaN
# 8         0.0
# 9         0.0
# 10        0.0
# 11        NaN
# 12        0.0
# 13        0.0
# 14        NaN
# 15        NaN
# 16        NaN
# 17        0.0
# 18        NaN
# 19        0.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        NaN
# 24        0.0
# 25        NaN
# 26        0.0
# 27        0.0
# 28        0.0
# 29        0.0
# ..        ...
# 418       NaN
# 419       NaN
# 420       0.0
# 421       NaN
# 422       0.0
# 423       0.0
# 424       NaN
# 425       0.0
# 426       NaN
# 427       NaN
# 428       NaN
# 429       NaN
# 430       NaN
# 431       NaN
# 432       NaN
# 433       NaN
# 434       NaN
# 435       0.0
# 436       0.0
# 437       NaN
# 438       0.0
# 439       0.0
# 440       0.0
# 441       0.0
# 442       0.0
# 443       0.0
# 444       NaN
# 445       0.0
# 446       NaN
# 447       0.0
#
# [448 rows x 6 columns]

# %% [markdown]
# ### Append geography details to the GeoCache dataframe
# Determine how well populated geography is at different hierarchy levels.

# %%
df_GeoCache = pd.merge(df_GeoCache, df_GeoList, on = 'Address', how = 'left' )

# %%
df_GeoCache.to_csv(path_or_buf = './GeoCache.csv', index = False)

# %% [markdown]
# ### Append Hierarchy 00 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache00 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_00')
]

df_GeoCache00.sample(10)
# Out:
#                             Geography     Hierarchy Address  \
# 340                            Oregon  Hierarchy_00     USA
# 222                          Bolgheri  Hierarchy_00   Italy
# 295               Contra Costa County  Hierarchy_00     USA
# 115       Vosne-Romanée Clos des Réas  Hierarchy_00  France
# 200                            Marche  Hierarchy_00   Italy
# 165                           IGP Var  Hierarchy_00  France
# 92   Puligny-Montrachet Les Combettes  Hierarchy_00  France
# 242                        Verona IGT  Hierarchy_00   Italy
# 224                        Carmignano  Hierarchy_00   Italy
# 235                           Tuscany  Hierarchy_00   Italy
#
#                                              loc  \
# 340  (United States, (39.7837304, -100.4458825))
# 222            (Italia, (42.6384261, 12.674297))
# 295  (United States, (39.7837304, -100.4458825))
# 115             (France, (46.603354, 1.8883335))
# 200            (Italia, (42.6384261, 12.674297))
# 165             (France, (46.603354, 1.8883335))
# 92              (France, (46.603354, 1.8883335))
# 242            (Italia, (42.6384261, 12.674297))
# 224            (Italia, (42.6384261, 12.674297))
# 235            (Italia, (42.6384261, 12.674297))
#
#                                point        lat        long  altitude
# 340  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882       0.0
# 222     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 295  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882       0.0
# 115      (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 200     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 165      (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 92       (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 242     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 224     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 235     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0

# %%
df_Wine00 = pd.merge(df_Wine, df_GeoCache00, on = 'Geography', how = 'left')

df_Wine00.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price        Winemaker  \
# 2636       1994.0   34    1992   92.0    14   Robert Mondavi
# 1705       2003.0    4    2001   95.0    60     Clos Mogador
# 1136       2009.0   35    2006   93.0    32         Viticcio
# 252        2018.0   53    2015   93.0    42    Sequoia Grove
# 971        2011.0   70    2009   91.0    20           Morgan
# 2326       1997.0   25    1993   96.0   100  Castello di Ama
# 749        2013.0   48    2011   93.0    39        Greywacke
# 2455       1996.0   54    1994   92.0    20        Rosenblum
# 1990       2001.0   89    1999   90.0    24         Rex Hill
# 861        2012.0   60    2009   96.0   135   Quilceda Creek
#
#                                         Wine Wine_Style          Grape_Blend  \
# 2636                   Zinfandel Napa Valley        Red            Zinfandel
# 1705                                 Priorat        Red                Blend
# 1136                Chianti Classico Riserva        Red              Chianti
# 252           Cabernet Sauvignon Napa Valley        Red  Cabernet Sauvignon
# 971   Chardonnay Monterey Metallico Un-Oaked      White          Chardonnay
# 2326                        Vigna l'Apparita        Red               Merlot
# 749                   Pinot Noir Marlborough        Red           Pinot Noir
# 2455   Zinfandel Mount Veeder Brandlin Ranch        Red            Zinfandel
# 1990            Pinot Noir Willamette Valley        Red           Pinot Noir
# 861       Cabernet Sauvignon Columbia Valley        Red  Cabernet Sauvignon
#
#           Blend_List  ... Best_Drink_from  Best_Drink_Through  \
# 2636             NaN  ...          1994.0                 NaN
# 1705  Rare Red Blend  ...          2005.0                 NaN
# 1136             NaN  ...          2010.0              2015.0
# 252              NaN  ...          2018.0              2030.0
# 971              NaN  ...          2011.0              2016.0
# 2326             NaN  ...          2000.0                 NaN
# 749              NaN  ...          2013.0              2024.0
# 2455             NaN  ...             NaN                 NaN
# 1990             NaN  ...          2001.0              2006.0
# 861              NaN  ...          2015.0              2024.0
#
#                                                  Review     Hierarchy  \
# 2636  Ripe, rich and supple, with plush cherry, rasp...  Hierarchy_00
# 1705  Suave, sophisticated, rich and concentrated, b...  Hierarchy_00
# 1136  Fabulous aromas of blackberry, dark chocolate ...  Hierarchy_00
# 252   Rich, smoky oak and plump dark berry, mocha, c...  Hierarchy_00
# 971   Fresh, intense and vibrant, with an aromatic h...  Hierarchy_00
# 2326  Powerful and exotic, this is the wine of the y...  Hierarchy_00
# 749   Elegant, with supple, fresh and lively flavors...  Hierarchy_00
# 2455  This wine has a great sense of harmony and fin...  Hierarchy_00
# 1990  Ripe, round and distinctive for its layers of ...  Hierarchy_00
# 861   Pure and impressively expressive, with focused...  Hierarchy_00
#
#           Address                                                loc  \
# 2636          USA        (United States, (39.7837304, -100.4458825))
# 1705        Spain                 (España, (39.3262345, -4.8380649))
# 1136        Italy                  (Italia, (42.6384261, 12.674297))
# 252           USA        (United States, (39.7837304, -100.4458825))
# 971           USA        (United States, (39.7837304, -100.4458825))
# 2326        Italy                  (Italia, (42.6384261, 12.674297))
# 749   New Zealand  (New Zealand / Aotearoa, (-41.5000831, 172.834...
# 2455          USA        (United States, (39.7837304, -100.4458825))
# 1990          USA        (United States, (39.7837304, -100.4458825))
# 861           USA        (United States, (39.7837304, -100.4458825))
#
#                                 point        lat        long altitude
# 2636  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 1705    (39.3262345, -4.8380649, 0.0)  39.326234   -4.838065      0.0
# 1136     (42.6384261, 12.674297, 0.0)  42.638426   12.674297      0.0
# 252   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 971   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 2326     (42.6384261, 12.674297, 0.0)  42.638426   12.674297      0.0
# 749   (-41.5000831, 172.8344077, 0.0) -41.500083  172.834408      0.0
# 2455  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 1990  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 861   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Append Hierarchy 01 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache01 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_01')
]

df_GeoCache01.sample(10)
# Out:
#                            Geography     Hierarchy  \
# 663                 Mendocino County  Hierarchy_01
# 356                           Agrelo  Hierarchy_01
# 456                Chambolle-Musigny  Hierarchy_01
# 652                      Edna Valley  Hierarchy_01
# 697               Horse Heaven Hills  Hierarchy_01
# 490                      Savennières  Hierarchy_01
# 430  Chassagne-Montrachet En Remilly  Hierarchy_01
# 454                     Bonnes Mares  Hierarchy_01
# 461                        Marsannay  Hierarchy_01
# 614                       Constantia  Hierarchy_01
#
#                         Address  \
# 663             California, USA
# 356          Mendoza, Argentina
# 456            Burgundy, France
# 652             California, USA
# 697             Washington, USA
# 490               Loire, France
# 430            Burgundy, France
# 454            Burgundy, France
# 461            Burgundy, France
# 614  Western Cape, South Africa
#
#                                                    loc  \
# 663  (California, United States, (36.7014631, -118....
# 356  (Mendoza, Argentina, (-34.787093049999996, -68...
# 456  (Bourgogne, France métropolitaine, France, (47...
# 652  (California, United States, (36.7014631, -118....
# 697  (Washington, District of Columbia, United Stat...
# 490  (Loire, Auvergne-Rhône-Alpes, France métropoli...
# 430  (Bourgogne, France métropolitaine, France, (47...
# 454  (Bourgogne, France métropolitaine, France, (47...
# 461  (Bourgogne, France métropolitaine, France, (47...
# 614  (Western Cape, South Africa, (-33.546977, 20.7...
#
#                                               point        lat        long  \
# 663                  (36.7014631, -118.755997, 0.0)  36.701463 -118.755997
# 356  (-34.787093049999996, -68.43818677312292, 0.0) -34.787093  -68.438187
# 456           (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486
# 652                  (36.7014631, -118.755997, 0.0)  36.701463 -118.755997
# 697                  (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558
# 490           (45.75385355, 4.045473682551104, 0.0)  45.753854    4.045474
# 430           (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486
# 454           (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486
# 461           (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486
# 614                     (-33.546977, 20.72753, 0.0) -33.546977   20.727530
#
#      altitude
# 663       0.0
# 356       0.0
# 456       0.0
# 652       0.0
# 697       0.0
# 490       0.0
# 430       0.0
# 454       0.0
# 461       0.0
# 614       0.0

# %%
df_Wine01 = pd.merge(df_Wine, df_GeoCache01, on = 'Geography', how = 'left')

df_Wine01.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price          Winemaker  \
# 1119       2009.0   18    1999   95.0    60             Argyle
# 494        2016.0   94    2014   90.0    32      William Fèvre
# 1176       2009.0   75    2008   90.0    14      M. Chapoutier
# 1823       2002.0   22    1997   98.0    89           Altesino
# 1544       2005.0   43    2003   93.0    16        Finca Luzón
# 147        2019.0   48    2015   93.0    40        G.D. Vajra
# 1151       2009.0   50    2006   93.0    45       Tablas Creek
# 938        2011.0   37    2009   93.0    30       Tablas Creek
# 835        2012.0   34    2010   93.0    29  Bertrand Stehelin
# 783        2013.0   82    2009   91.0    30  Mamete Prevostini
#
#                                                    Wine Wine_Style  \
# 1119                  Extended Tirage Willamette Valley  Sparkling
# 494                                     Chablis Domaine      White
# 1176  Côtes du Roussillon-Villages Les Vignes de Bil...        Red
# 1823                   Brunello di Montalcino Montosoli        Red
# 1544                             Jumilla Altos de Luzón        Red
# 147                                        Barolo Albe         Red
# 1151                   Esprit de Beaucastel Paso Robles        Red
# 938                         Côtes de Tablas Paso Robles        Red
# 835                                            Gigondas        Red
# 783                       Valtellina Superiore Sassella        Red
#
#                   Grape_Blend  \
# 1119  Chardonnay - Pinot Noir
# 494               Chardonnay
# 1176                    Blend
# 1823   Brunello di Montalcino
# 1544                    Blend
# 147                     Blend
# 1151                    Blend
# 938                     Blend
# 835                     Blend
# 783                  Nebbiolo
#
#                                              Blend_List  ... Best_Drink_from  \
# 1119                                                NaN  ...          2009.0
# 494                                                 NaN  ...          2016.0
# 1176                        Carignan - Grenache – Syrah  ...          2010.0
# 1823                                                NaN  ...          2004.0
# 1544  Monastrell (Mourvèdre), Cabernet Sauvignon and...  ...          2005.0
# 147                                            Nebbiolo  ...          2021.0
# 1151           Mourvèdre, Grenache, Syrah and Counoise   ...          2009.0
# 938            Grenache, Syrah, Counoise and Mourvèdre   ...          2011.0
# 835                            Southern Rhone Red Blend  ...          2014.0
# 783                                                 NaN  ...          2013.0
#
#       Best_Drink_Through                                             Review  \
# 1119                 NaN  Elegant, with very fine bubbles and complex sp...
# 494               2018.0  This is delicate, featuring lemon, herb and st...
# 1176              2014.0  This muscular red shows concentrated flavors o...
# 1823                 NaN  Complex aromas of grilled meat and cherry, wit...
# 1544              2010.0  Ripe and luscious. This rich red is bursting w...
# 147               2036.0  Pretty, featuring rose, cherry, raspberry and ...
# 1151              2014.0  Well-balanced, intense yet elegant. Full-bodie...
# 938               2017.0  Charmingly fruity, supple and fun to drink, ex...
# 835               2022.0  Powerfully rendered, with thickly layered blac...
# 783               2023.0  Expressive, with a floral note, hints of aroma...
#
#          Hierarchy                       Address  \
# 1119  Hierarchy_01                   Oregon, USA
# 494   Hierarchy_01              Burgundy, France
# 1176  Hierarchy_01  Languedoc-Roussillon, France
# 1823  Hierarchy_01                Tuscany, Italy
# 1544  Hierarchy_01                 Murcia, Spain
# 147   Hierarchy_01    Piedmont | Piemonte, Italy
# 1151  Hierarchy_01               California, USA
# 938   Hierarchy_01               California, USA
# 835   Hierarchy_01                 Rhône, France
# 783   Hierarchy_01               Lombardy, Italy
#
#                                                     loc  \
# 1119  (Oregon, United States, (43.9792797, -120.7372...
# 494   (Bourgogne, France métropolitaine, France, (47...
# 1176  (Languedoc-Roussillon, France métropolitaine, ...
# 1823        (Toscana, Italia, (43.4586541, 11.1389204))
# 1544  (Murcia, Área Metropolitana de Murcia, Región ...
# 147   (Piedmont Properties, 78, SP50, San Marzano Ol...
# 1151  (California, United States, (36.7014631, -118....
# 938   (California, United States, (36.7014631, -118....
# 835   (Rhône, Circonscription départementale du Rhôn...
# 783        (Lombardia, Italia, (45.5703694, 9.7732524))
#
#                                       point        lat        long altitude
# 1119         (43.9792797, -120.737257, 0.0)  43.979280 -120.737257      0.0
# 494   (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486      0.0
# 1176  (43.65420305, 3.674669940206605, 0.0)  43.654203    3.674670      0.0
# 1823          (43.4586541, 11.1389204, 0.0)  43.458654   11.138920      0.0
# 1544          (37.9923795, -1.1305431, 0.0)  37.992379   -1.130543      0.0
# 147            (44.7605629, 8.2998538, 0.0)  44.760563    8.299854      0.0
# 1151         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 938          (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 835    (45.8802348, 4.564533629559522, 0.0)  45.880235    4.564534      0.0
# 783            (45.5703694, 9.7732524, 0.0)  45.570369    9.773252      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Save files for use in other notebooks

# %%
df_Wine00.to_csv(path_or_buf = './Wine_Hier00.csv', index = False)
df_Wine01.to_csv(path_or_buf = './Wine_Hier01.csv', index = False)
