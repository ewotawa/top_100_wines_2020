# %% [markdown]
# # GeoCache: *Wine Spectator*'s Top 100 Wines, 1988-2020
# List available online on *Wine Spectator*'s [Top 100 Lists web site](https://top100.winespectator.com/lists/).

# %% [markdown]
# ## File Setup

# %%
# import and initialize main python libraries
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# import libraries for file navigation
import os
import shutil
import glob
from pandas_ods_reader import read_ods

# import other packages
from scipy import stats
from sklearn import linear_model

# import geo packages
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon

# import Geopy packages
import geopy
from geopy.geocoders import Nominatim

# %%
# initialize vizualization set
sns.set(style="whitegrid", palette="colorblind", color_codes=True)
sns.mpl.rc("figure", figsize=(10, 6))

# Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Dataframe Exploration

# %%
# Note: save CSV files in UTF-8 format to preserve special characters.
df_Wine = pd.read_csv('./CSV_Wines.csv')
df_GeoCache = pd.read_csv('./CSV_GeoCache.csv')
df_GeoList = pd.read_csv('./CSV_GeoList.csv')

# %%
df_Wine.shape
# Out:
# (3301, 18)

# %%
df_Wine.dtypes
# Out:
# Review_Year           float64
# Rank                   object
# Vintage                object
# Score                 float64
# Price                  object
# Winemaker              object
# Wine                   object
# Wine_Style             object
# Grape_Blend            object
# Blend_List             object
# Geography              object
# Cases_Made            float64
# Cases_Imported        float64
# Reviewer               object
# Drink_now             float64
# Best_Drink_from       float64
# Best_Drink_Through    float64
# Review                 object
# dtype: object

# %%
df_GeoCache.shape
# Out:
# (1226, 3)

# %%
df_GeoList.shape
# Out:
# (448, 1)

# %%
df_Wine.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price             Winemaker  \
# 3057       1990.0   58    1987   95.0   170             Jean Gros
# 218        2018.0   19    2016   94.0    17            San Felice
# 161        2019.0   62    2015   90.0    15  Viña Haras de Pirque
# 555        2015.0   56    2010   93.0    44                  Cune
# 1589       2005.0   90    2003   92.0    35            Gunderloch
# 2548       1995.0   49    1990   93.0    30        Castello Banfi
# 2257       1998.0   24    1995   96.0   110         Harlan Estate
# 456        2016.0   57    2015   91.0    20     Cave de Roquebrun
# 2632       1994.0   33    1992   92.0    14     Domaine du Closel
# 1729       2003.0   30    2000   97.0    60             E. Guigal
#
#                                                    Wine Wine_Style  \
# 3057                                         Richebourg        Red
# 218                                    Chianti Classico        Red
# 161   Cabernet Sauvignon Maipo Valley Hussonet Gran ...        Red
# 555                              Rioja Imperial Reserva        Red
# 1589  Riesling Spätlese Rheinhessen Nackenheim Rothe...      White
# 2548                             Brunello di Montalcino        Red
# 2257                                        Napa Valley        Red
# 456          St.-Chinian-Roquebrun La Grange des Combes        Red
# 2632                         Savennières Cuvée Spéciale      White
# 1729                                          Hermitage        Red
#
#                  Grape_Blend                      Blend_List  \
# 3057              Pinot Noir                             NaN
# 218                  Chianti                             NaN
# 161      Cabernet Sauvignon                              NaN
# 555                    Rioja                             NaN
# 1589                Riesling                             NaN
# 2548  Brunello di Montalcino                             NaN
# 2257                   Blend              Bordeaux Blend Red
# 456                    Blend  Syrah, Grenache and Mourvèdre
# 2632            Chenin Blanc                             NaN
# 1729          Shiraz | Syrah                             NaN
#
#                    Geography  Cases_Made  Cases_Imported Reviewer  Drink_now  \
# 3057              Richebourg       900.0             NaN      NaN        1.0
# 218                  Chianti     25000.0             NaN       BS        NaN
# 161             Maipo Valley         NaN          2500.0       KM        1.0
# 555                    Rioja         NaN          1500.0       TM        NaN
# 1589             Rheinhessen         NaN           500.0       BS        1.0
# 2548  Brunello di Montalcino         NaN             NaN      NaN        NaN
# 2257             Napa Valley      1185.0             NaN       JL        NaN
# 456    St.-Chinian-Roquebrun     12000.0             NaN       GS        1.0
# 2632             Savennières      2600.0             NaN      NaN        1.0
# 1729               Hermitage      4580.0             NaN       PM        1.0
#
#       Best_Drink_from  Best_Drink_Through  \
# 3057           1990.0                 NaN
# 218            2020.0              2036.0
# 161            2019.0              2024.0
# 555            2016.0              2030.0
# 1589           2005.0              2020.0
# 2548           1999.0                 NaN
# 2257           2001.0              2010.0
# 456            2016.0              2022.0
# 2632           1994.0                 NaN
# 1729           2003.0              2012.0
#
#                                                  Review
# 3057  The class shows clearly in this wine, sending ...
# 218   Expressive and smooth, this hits all the right...
# 161   Big and fresh-tasting, with concentrated dark ...
# 555   Smoky and tarry notes give this rich red an au...
# 1589  Opulent and concentrated, exhibiting mango, pa...
# 2548  A wonderful Brunello boasting mineral, violet,...
# 2257  A tremendous effort with all kinds of extra fl...
# 456   A muscular but polished red, with brooding bla...
# 2632  Imagine an apple tart glazed with honey and le...
# 1729  Ultrarich and ultrathick. A full-bodied, stunn...

# %%
df_GeoCache.sample(10)
# Out:
#                            Geography     Hierarchy  \
# 684                       New Mexico  Hierarchy_01
# 339                Willamette Valley  Hierarchy_00
# 525                         Rheingau  Hierarchy_01
# 850                           Rhodes  Hierarchy_02
# 954                  Howell Mountain  Hierarchy_02
# 1155  Morey-St.-Denis Monts Luisants  Hierarchy_04
# 1048              Romanée St.-Vivant  Hierarchy_03
# 1202        Pommard Les Boucherottes  Hierarchy_05
# 297                      Edna Valley  Hierarchy_00
# 693         Yamhill-Carlton District  Hierarchy_01
#
#                                                 Address
# 684                                     New Mexico, USA
# 339                                                 USA
# 525                                   Rheingau, Germany
# 850                      Rhodes, Aegean Islands, Greece
# 954                        North Coast, California, USA
# 1155  Morey-St.-Denis Premier Cru, Morey-St.-Denis, ...
# 1048     Vosne-Romanée, Côte de Nuits, Burgundy, France
# 1202  Pommard Les Boucherottes, Pommard Premier Cru,...
# 297                                                 USA
# 693                                         Oregon, USA

# %%
df_GeoList.sample(10)
# Out:
#                                                Address
# 237        Meursault, Côte de Beaune, Burgundy, France
# 110  Contra Costa County, San Francisco Bay, Centra...
# 137                                      Dão, Portugal
# 422                      Vin de Corse, Corsica, France
# 329               Riverina, New South Wales, Australia
# 343  San Luis Obispo County, Central Coast, Califor...
# 418     Verdicchio dei Castelli di Jesi, Marche, Italy
# 96                     Chinon, Touraine, Loire, France
# 339  San Benito County, Central Coast, California, USA
# 325            Ribera del Guadiana, Extremadura, Spain

# %% [markdown]
# ### Geocode the Address dataframe
# Reference: [Python’s geocoding — Convert a list of addresses into a map](https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6)

# %%
# Initialize Nominatim into geolocator variable.
geolocator = Nominatim(user_agent='wine app')

# %%
geolocator.geocode('Castilla y León, Spain').raw
# Out:
# {'place_id': 258252333,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 349041,
#  'boundingbox': ['40.0824504', '43.2382034', '-7.077073', '-1.7753716'],
#  'lat': '41.8037172',
#  'lon': '-4.7471726',
#  'display_name': 'Castilla y León, España',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.9625997816800999,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}

# %%
geolocator.geocode('Castilla y León, Spain').point
# Out:
# Point(41.8037172, -4.7471726, 0.0)

# %%
# Apply geolocator to the Address column in the GeoList dataframe.
df_GeoList['loc'] = df_GeoList['Address'].apply(geolocator.geocode)

# %%
# Get .point containing lat/long from Geocode response, if not none.
df_GeoList['point'] = df_GeoList['loc'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# Split the .point column into separate columns for lat, long, and altitude
df_GeoList[['lat', 'long', 'altitude']] = pd.DataFrame(df_GeoList['point'].to_list(), index=df_GeoList.index)

# %%
df_GeoList
# Out:
#                                                Address  \
# 0                                       Abruzzo, Italy
# 1           Adelaide Hills, South Australia, Australia
# 2                               Aegean Islands, Greece
# 3             Aglianico del Vulture, Basilicata, Italy
# 4                           Agrelo, Mendoza, Argentina
# 5                     Alba, Piedmont | Piemonte, Italy
# 6                                   Alentejo, Portugal
# 7    Alexander Valley, Sonoma County, North Coast, ...
# 8                            Alicante, Valencia, Spain
# 9                   Almansa, Castilla La Mancha, Spain
# 10                                      Alsace, France
# 11   Alto Adige Terlano, Alto Adige, Sudtirol, Tren...
# 12    Alto Adige, Sudtirol, Trentino-Alto Adige, Italy
# 13    Alto Adige, Sudtirol, Trentino,Alto Adige, Italy
# 14    Amador County, Sierra Foothills, California, USA
# 15           Amarone della Valpolicella, Veneto, Italy
# 16                 Amyndaio, Macedonia, Greece, Greece
# 17                                    Andalucia, Spain
# 18   Anderson Valley, Mendocino County, North Coast...
# 19                                Anjou, Loire, France
# 20                     Apalta, Colchagua Valley, Chile
# 21                            Apremont, Savoie, France
# 22                                       Aragon, Spain
# 23                       Arbois Pupillin, Jura, France
# 24                                           Argentina
# 25   Arroyo Grande Valley, San Luis Obispo County, ...
# 26                               Auckland, New Zealand
# 27                                           Australia
# 28                                             Austria
# 29                            Bandol, Provence, France
# ..                                                 ...
# 418     Verdicchio dei Castelli di Jesi, Marche, Italy
# 419              Verona IGT, Veneto IGT, Veneto, Italy
# 420                                Victoria, Australia
# 421  Vigneti delle Dolomiti IGT, Trentino,Alto Adig...
# 422                      Vin de Corse, Corsica, France
# 423                               Vin de Pays , France
# 424       Vino Nobile di Montepulciano, Tuscany, Italy
# 425                           Vinsobres, Rhône, France
# 426           Volnay, Côte de Beaune, Burgundy, France
# 427  Vosne-Romanée Aux Brûlées, Vosne-Romanée Premi...
# 428  Vosne-Romanée Clos des Réas , Vosne-Romanée Pr...
# 429  Vosne-Romanée Cros Parantoux, Vosne-Romanée Pr...
# 430  Vosne-Romanée Les Beaux Monts, Vosne-Romanée P...
# 431  Vosne-Romanée Les Chaumes, Vosne-Romanée Premi...
# 432  Vosne-Romanée Premier Cru, Vosne-Romanée, Côte...
# 433     Vosne-Romanée, Côte de Nuits, Burgundy, France
# 434           Vougeot, Côte de Nuits, Burgundy, France
# 435                   Vouvray, Touraine, Loire, France
# 436                                    Wachau, Austria
# 437  Walker Bay, Cape South Coast, Western Cape, So...
# 438                Walla Walla Valley, Washington, USA
# 439                                    Washington, USA
# 440                       Western Australia, Australia
# 441                         Western Cape, South Africa
# 442                     Willamette Valley, Oregon, USA
# 443                     Yakima Valley, Washington, USA
# 444  Yamhill-Carlton District, Willamette Valley, O...
# 445                  Yarra Valley, Victoria, Australia
# 446  Yamhill-Carlton District, Willamette Valley, O...
# 447                  Yarra Valley, Victoria, Australia
#
#                                                    loc  \
# 0            (Abruzzo, Italia, (42.227681, 13.854983))
# 1    (Adelaide Hills Council, South Australia, Aust...
# 2    (Aegean, Σάμη - Αγία Ευφημία, Καραβόμυλος, Δήμ...
# 3                                                 None
# 4    (Agrelo, Distrito Agrelo, Departamento Luján d...
# 5                                                 None
# 6       (Alentejo, Portugal, (38.0551003, -7.8605799))
# 7                                                 None
# 8    (Alacant / Alicante, l'Alacantí, Alacant / Ali...
# 9    (Almansa, Albacete, Castilla-La Mancha, 02640,...
# 10   (Alsace, France métropolitaine, France, (48.24...
# 11                                                None
# 12   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 13   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 14                                                None
# 15                                                None
# 16                                                None
# 17       (Andalucía, España, (37.3399964, -4.5811614))
# 18                                                None
# 19   (Anjoux, Sagy, Louhans, Saône-et-Loire, Bourgo...
# 20   (Viña Apalta, Millahue de Apalta, Santa Cruz, ...
# 21   (Apremont, Chambéry, Savoie, Auvergne-Rhône-Al...
# 22          (Aragón, España, (41.3787291, -0.7639373))
# 23                                                None
# 24             (Argentina, (-34.9964963, -64.9672817))
# 25                                                None
# 26   (Auckland, Waitematā, Auckland, 1010, New Zeal...
# 27                 (Australia, (-24.7761086, 134.755))
# 28               (Österreich, (47.2000338, 13.199959))
# 29   (Bandol, Toulon, Var, Provence-Alpes-Côte d'Az...
# ..                                                 ...
# 418                                               None
# 419                                               None
# 420  (Victoria, Australia, (-36.5986096, 144.6780052))
# 421                                               None
# 422  (Les Plaisirs du Vin, Rue du Général de Gaulle...
# 423  (Le Bois Vien, Craon, Château-Gontier, Mayenne...
# 424                                               None
# 425  (Vinsobres, Nyons, Drôme, Auvergne-Rhône-Alpes...
# 426                                               None
# 427                                               None
# 428                                               None
# 429                                               None
# 430                                               None
# 431                                               None
# 432                                               None
# 433                                               None
# 434                                               None
# 435  (Rue de Vouvray, Auzouer-en-Touraine, Loches, ...
# 436  (Wachau, Bezirk Krems, Niederösterreich, Öster...
# 437                                               None
# 438  (Walla Walla, Walla Walla County, Washington, ...
# 439  (Washington, District of Columbia, United Stat...
# 440  (Western Australia, Australia, (-25.2303005, 1...
# 441  (Western Cape, South Africa, (-33.546977, 20.7...
# 442  (Willamette, West Linn, Metro, Oregon, 97068, ...
# 443  (Yakima, Yakima County, Washington, United Sta...
# 444                                               None
# 445  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
# 446                                               None
# 447  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
#
#                                              point        lat        long  \
# 0                      (42.227681, 13.854983, 0.0)  42.227681   13.854983
# 1    (-34.901351649999995, 138.8293202817461, 0.0) -34.901352  138.829320
# 2                    (38.2504094, 20.6304217, 0.0)  38.250409   20.630422
# 3                                             None        NaN         NaN
# 4                  (-33.1184629, -68.8859261, 0.0) -33.118463  -68.885926
# 5                                             None        NaN         NaN
# 6                    (38.0551003, -7.8605799, 0.0)  38.055100   -7.860580
# 7                                             None        NaN         NaN
# 8                     (38.353738, -0.4901846, 0.0)  38.353738   -0.490185
# 9                    (38.8682065, -1.0978627, 0.0)  38.868206   -1.097863
# 10             (48.24917645, 7.4074699518555, 0.0)  48.249176    7.407470
# 11                                            None        NaN         NaN
# 12          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 13          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 14                                            None        NaN         NaN
# 15                                            None        NaN         NaN
# 16                                            None        NaN         NaN
# 17                   (37.3399964, -4.5811614, 0.0)  37.339996   -4.581161
# 18                                            None        NaN         NaN
# 19                     (46.564187, 5.3193257, 0.0)  46.564187    5.319326
# 20                 (-34.6239248, -71.2671251, 0.0) -34.623925  -71.267125
# 21                         (45.5132, 5.95937, 0.0)  45.513200    5.959370
# 22                   (41.3787291, -0.7639373, 0.0)  41.378729   -0.763937
# 23                                            None        NaN         NaN
# 24                 (-34.9964963, -64.9672817, 0.0) -34.996496  -64.967282
# 25                                            None        NaN         NaN
# 26                  (-36.852095, 174.7631803, 0.0) -36.852095  174.763180
# 27                     (-24.7761086, 134.755, 0.0) -24.776109  134.755000
# 28                    (47.2000338, 13.199959, 0.0)  47.200034   13.199959
# 29                    (43.1357717, 5.7523647, 0.0)  43.135772    5.752365
# ..                                             ...        ...         ...
# 418                                           None        NaN         NaN
# 419                                           None        NaN         NaN
# 420                (-36.5986096, 144.6780052, 0.0) -36.598610  144.678005
# 421                                           None        NaN         NaN
# 422                   (41.5903081, 9.2780396, 0.0)  41.590308    9.278040
# 423                  (47.8653429, -0.9011409, 0.0)  47.865343   -0.901141
# 424                                           None        NaN         NaN
# 425                   (44.3339938, 5.0609674, 0.0)  44.333994    5.060967
# 426                                           None        NaN         NaN
# 427                                           None        NaN         NaN
# 428                                           None        NaN         NaN
# 429                                           None        NaN         NaN
# 430                                           None        NaN         NaN
# 431                                           None        NaN         NaN
# 432                                           None        NaN         NaN
# 433                                           None        NaN         NaN
# 434                                           None        NaN         NaN
# 435                   (47.5835908, 0.9204818, 0.0)  47.583591    0.920482
# 436           (48.3275563, 15.41162578949626, 0.0)  48.327556   15.411626
# 437                                           None        NaN         NaN
# 438                (46.0667277, -118.3393456, 0.0)  46.066728 -118.339346
# 439                 (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558
# 440                (-25.2303005, 121.0187246, 0.0) -25.230300  121.018725
# 441                    (-33.546977, 20.72753, 0.0) -33.546977   20.727530
# 442                (45.3442868, -122.6670374, 0.0)  45.344287 -122.667037
# 443                 (46.601557, -120.5108421, 0.0)  46.601557 -120.510842
# 444                                           None        NaN         NaN
# 445                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
# 446                                           None        NaN         NaN
# 447                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
#
#      altitude
# 0         0.0
# 1         0.0
# 2         0.0
# 3         NaN
# 4         0.0
# 5         NaN
# 6         0.0
# 7         NaN
# 8         0.0
# 9         0.0
# 10        0.0
# 11        NaN
# 12        0.0
# 13        0.0
# 14        NaN
# 15        NaN
# 16        NaN
# 17        0.0
# 18        NaN
# 19        0.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        NaN
# 24        0.0
# 25        NaN
# 26        0.0
# 27        0.0
# 28        0.0
# 29        0.0
# ..        ...
# 418       NaN
# 419       NaN
# 420       0.0
# 421       NaN
# 422       0.0
# 423       0.0
# 424       NaN
# 425       0.0
# 426       NaN
# 427       NaN
# 428       NaN
# 429       NaN
# 430       NaN
# 431       NaN
# 432       NaN
# 433       NaN
# 434       NaN
# 435       0.0
# 436       0.0
# 437       NaN
# 438       0.0
# 439       0.0
# 440       0.0
# 441       0.0
# 442       0.0
# 443       0.0
# 444       NaN
# 445       0.0
# 446       NaN
# 447       0.0
#
# [448 rows x 6 columns]

# %% [markdown]
# ### Append geography details to the GeoCache dataframe
# Determine how well populated geography is at different hierarchy levels.

# %%
df_GeoCache = pd.merge(df_GeoCache, df_GeoList, on = 'Address', how = 'left' )

# %%
df_GeoCache.to_csv(path_or_buf = './GeoCache.csv', index = False)

# %% [markdown]
# ### Append Hierarchy 00 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache00 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_00')
]

df_GeoCache00.sample(10)
# Out:
#                  Geography     Hierarchy       Address  \
# 235                Tuscany  Hierarchy_00         Italy
# 257         Hemel-en-Aarde  Hierarchy_00  South Africa
# 344     Walla Walla Valley  Hierarchy_00           USA
# 57                  Graves  Hierarchy_00        France
# 228  Morellino di Scansano  Hierarchy_00         Italy
# 239               Prosecco  Hierarchy_00         Italy
# 241   Valpolicella Ripasso  Hierarchy_00         Italy
# 80     Corton Les Renardes  Hierarchy_00        France
# 184                   Cirò  Hierarchy_00         Italy
# 17              Coonawarra  Hierarchy_00     Australia
#
#                                              loc  \
# 235            (Italia, (42.6384261, 12.674297))
# 257     (South Africa, (-28.8166236, 24.991639))
# 344  (United States, (39.7837304, -100.4458825))
# 57              (France, (46.603354, 1.8883335))
# 228            (Italia, (42.6384261, 12.674297))
# 239            (Italia, (42.6384261, 12.674297))
# 241            (Italia, (42.6384261, 12.674297))
# 80              (France, (46.603354, 1.8883335))
# 184            (Italia, (42.6384261, 12.674297))
# 17           (Australia, (-24.7761086, 134.755))
#
#                                point        lat        long  altitude
# 235     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 257    (-28.8166236, 24.991639, 0.0) -28.816624   24.991639       0.0
# 344  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882       0.0
# 57       (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 228     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 239     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 241     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 80       (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 184     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 17       (-24.7761086, 134.755, 0.0) -24.776109  134.755000       0.0

# %%
df_Wine00 = pd.merge(df_Wine, df_GeoCache00, on = 'Geography', how = 'left')

df_Wine00.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price                 Winemaker  \
# 2101       2000.0  100    1998   91.0    29  Freie Weingärtner Wachau
# 3268       1988.0   66    1985   93.0    25          Château La Croix
# 890        2012.0   89    2009   92.0    40                     Honig
# 3054       1990.0   52    1987   93.0    24              Clos du Bois
# 897        2012.0   96    2009   94.0    75                 Pahlmeyer
# 763        2013.0   62    2010   91.0    22             Concha y Toro
# 2222       1998.0    7    1997   95.0    40     Château de Beaucastel
# 3249       1988.0   47    1984   94.0    20         Chateau Montelena
# 610        2014.0    9    2010   95.0   125             Concha y Toro
# 1644       2004.0   43    2001   93.0    26    Pago de los Capellanes
#
#                                                    Wine Wine_Style  \
# 2101  Riesling Smaragd Trocken Wachau Spitzer Singer...      White
# 3268                                            Pomerol        Red
# 890                      Cabernet Sauvignon Napa Valley        Red
# 3054    Chardonnay Alexander Valley Winemaker's Reserve      White
# 897                                  Merlot Napa Valley        Red
# 763                   Syrah Buin Marqués de Casa Concha        Red
# 2222                          Châteauneuf-du-Pape White      White
# 3249                     Cabernet Sauvignon Napa Valley        Red
# 610          Cabernet Sauvignon Puente Alto Don Melchor        Red
# 1644                           Ribera del Duero Crianza        Red
#
#               Grape_Blend              Blend_List  ... Best_Drink_from  \
# 2101             Riesling                     NaN  ...          2001.0
# 3268              Pomerol                     NaN  ...          1991.0
# 890   Cabernet Sauvignon                      NaN  ...          2013.0
# 3054          Chardonnay                      NaN  ...          1990.0
# 897                Merlot                     NaN  ...          2012.0
# 763        Shiraz | Syrah                     NaN  ...          2014.0
# 2222  Châteauneuf-du-Pape                     NaN  ...          1998.0
# 3249  Cabernet Sauvignon                      NaN  ...          1998.0
# 610   Cabernet Sauvignon                      NaN  ...          2014.0
# 1644                Blend  Cabernet – Tempranillo  ...          2004.0
#
#       Best_Drink_Through                                             Review  \
# 2101              2006.0  Multidimensional. Intense aromas of licorice a...
# 3268              1993.0  Rich and powerful yet elegant and decadent wit...
# 890               2023.0  Dense and tight, exhibiting a firm core of loa...
# 3054              1993.0  A rich, smooth, creamy style that offers a bro...
# 897               2018.0  Plush and richly structured, but with a dense,...
# 763               2018.0  This compact red needs aeration, featuring lay...
# 2222              2010.0  This classy, distinctive white shows wonderful...
# 3249                 NaN  Deep, dark, concentrated and ripe, showing mas...
# 610               2020.0  Refined and elegant, with silky tannins behind...
# 1644              2015.0  This distinctive red is graceful on the palate...
#
#          Hierarchy  Address                                          loc  \
# 2101  Hierarchy_00  Austria        (Österreich, (47.2000338, 13.199959))
# 3268  Hierarchy_00   France             (France, (46.603354, 1.8883335))
# 890   Hierarchy_00      USA  (United States, (39.7837304, -100.4458825))
# 3054  Hierarchy_00      USA  (United States, (39.7837304, -100.4458825))
# 897   Hierarchy_00      USA  (United States, (39.7837304, -100.4458825))
# 763   Hierarchy_00    Chile          (Chile, (-31.7613365, -71.3187697))
# 2222  Hierarchy_00   France             (France, (46.603354, 1.8883335))
# 3249  Hierarchy_00      USA  (United States, (39.7837304, -100.4458825))
# 610   Hierarchy_00    Chile          (Chile, (-31.7613365, -71.3187697))
# 1644  Hierarchy_00    Spain           (España, (39.3260685, -4.8379791))
#
#                                 point        lat        long altitude
# 2101     (47.2000338, 13.199959, 0.0)  47.200034   13.199959      0.0
# 3268      (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 890   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 3054  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 897   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 763   (-31.7613365, -71.3187697, 0.0) -31.761336  -71.318770      0.0
# 2222      (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 3249  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 610   (-31.7613365, -71.3187697, 0.0) -31.761336  -71.318770      0.0
# 1644    (39.3260685, -4.8379791, 0.0)  39.326068   -4.837979      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Append Hierarchy 01 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache01 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_01')
]

df_GeoCache01.sample(10)
# Out:
#              Geography     Hierarchy                     Address  \
# 615        Groenekloof  Hierarchy_01  Western Cape, South Africa
# 564             Langhe  Hierarchy_01  Piedmont | Piemonte, Italy
# 374    Limestone Coast  Hierarchy_01  South Australia, Australia
# 698       Red Mountain  Hierarchy_01             Washington, USA
# 566              Nardò  Hierarchy_01               Puglia, Italy
# 396             Apalta  Hierarchy_01     Colchagua Valley, Chile
# 456  Chambolle-Musigny  Hierarchy_01            Burgundy, France
# 538    Val di Neto IGT  Hierarchy_01             Calabria, Italy
# 451           Santenay  Hierarchy_01            Burgundy, France
# 673        Napa Valley  Hierarchy_01             California, USA
#
#                                                    loc  \
# 615  (Western Cape, South Africa, (-33.546977, 20.7...
# 564  (Piedmont Properties, 78, SP50, San Marzano Ol...
# 374  (South Australia, Australia, (-30.5343665, 135...
# 698  (Washington, District of Columbia, United Stat...
# 566         (Puglia, Italia, (40.9842539, 16.6210027))
# 396  (Colchagua, Palmilla, Provincia de Colchagua, ...
# 456  (Bourgogne, France métropolitaine, France, (47...
# 538       (Calabria, Italia, (39.0565974, 16.5249864))
# 451  (Bourgogne, France métropolitaine, France, (47...
# 673  (California, United States, (36.7014631, -118....
#
#                                      point        lat        long  altitude
# 615            (-33.546977, 20.72753, 0.0) -33.546977   20.727530       0.0
# 564           (44.7605629, 8.2998538, 0.0)  44.760563    8.299854       0.0
# 374        (-30.5343665, 135.6301212, 0.0) -30.534367  135.630121       0.0
# 698         (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558       0.0
# 566          (40.9842539, 16.6210027, 0.0)  40.984254   16.621003       0.0
# 396         (-34.548228, -71.4013194, 0.0) -34.548228  -71.401319       0.0
# 456  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 538          (39.0565974, 16.5249864, 0.0)  39.056597   16.524986       0.0
# 451  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 673         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997       0.0

# %%
df_Wine01 = pd.merge(df_Wine, df_GeoCache01, on = 'Geography', how = 'left')

df_Wine01.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price                         Winemaker  \
# 63         2020.0   64    2018   92.0    35                          La Crema
# 1522       2005.0   21    2002   97.0    85             Barossa Valley Estate
# 760        2013.0   59    2010   95.0    72                             Donum
# 83         2020.0   84    2019   94.0    35                             Delas
# 1446       2006.0   45    2004   95.0    85                Tenuta Sette Ponti
# 775        2013.0   74    2011   93.0    55                             Lucia
# 3104       1989.0    2    1986   97.0    32               Château Clerc Milon
# 3106       1989.0    4    1986   97.0    58  Château Pichon-Longueville Baron
# 1652       2004.0   51    2003   92.0    24                         Two Hands
# 227        2018.0   28    2016   93.0    20                            Penley
#
#                                                   Wine Wine_Style  \
# 63                       Pinot Noir Willamette Valley         Red
# 1522            Shiraz Barossa Valley E&E Black Pepper        Red
# 760                                Pinot Noir Carneros        Red
# 83                      St.-Joseph White Les Challeys       White
# 1446                                     Toscana Oreno        Red
# 775   Pinot Noir Santa Lucia Highlands Garys' Vineyard        Red
# 3104                                          Pauillac        Red
# 3106                                          Pauillac        Red
# 1652                 Shiraz McLaren Vale Angel's Share        Red
# 227              Cabernet Sauvignon Coonawarra Phoenix        Red
#
#               Grape_Blend                                  Blend_List  ...  \
# 63             Pinot Noir                                         NaN  ...
# 1522       Shiraz | Syrah                                         NaN  ...
# 760            Pinot Noir                                         NaN  ...
# 83                  Blend                        Marsanne – Roussanne  ...
# 1446                Blend  Merlot, Sangiovese and Cabernet Sauvignon   ...
# 775            Pinot Noir                                         NaN  ...
# 3104                Blend                          Bordeaux Blend Red  ...
# 3106                Blend                          Bordeaux Blend Red  ...
# 1652       Shiraz | Syrah                                         NaN  ...
# 227   Cabernet Sauvignon                                          NaN  ...
#
#      Best_Drink_from  Best_Drink_Through  \
# 63            2020.0              2027.0
# 1522          2010.0              2022.0
# 760           2013.0              2023.0
# 83            2020.0              2027.0
# 1446          2009.0                 NaN
# 775           2013.0              2021.0
# 3104          1998.0              2009.0
# 3106             NaN                 NaN
# 1652          2007.0              2015.0
# 227           2018.0              2030.0
#
#                                                  Review     Hierarchy  \
# 63    Sleek and vibrant, with snappy raspberry and r...  Hierarchy_01
# 1522  Dark, juicy and profound, with layer upon laye...  Hierarchy_01
# 760   Offers ebullient raspberry and black cherry fl...  Hierarchy_01
# 83    Very bright and engaging style, with a flurry ...  Hierarchy_01
# 1446  Fabulous aromas of ripe blackberry, cappuccino...  Hierarchy_01
# 775   Offers a rich, potent, vivid mix of dark berry...  Hierarchy_01
# 3104  Seductively rich and supple with layers of ele...  Hierarchy_01
# 3106  Amazingly elegant and complex featuring rich c...  Hierarchy_01
# 1652  Not a huge mouthful, but it unfolds its flavor...  Hierarchy_01
# 227   Dense, with sink-your-teeth-into-them tannins ...  Hierarchy_01
#
#                          Address  \
# 63                   Oregon, USA
# 1522  South Australia, Australia
# 760              California, USA
# 83                 Rhône, France
# 1446              Tuscany, Italy
# 775              California, USA
# 3104            Bordeaux, France
# 3106            Bordeaux, France
# 1652  South Australia, Australia
# 227   South Australia, Australia
#
#                                                     loc  \
# 63    (Oregon, United States, (43.9792797, -120.7372...
# 1522  (South Australia, Australia, (-30.5343665, 135...
# 760   (California, United States, (36.7014631, -118....
# 83    (Rhône, Circonscription départementale du Rhôn...
# 1446        (Toscana, Italia, (43.4586541, 11.1389204))
# 775   (California, United States, (36.7014631, -118....
# 3104  (Bordeaux, Gironde, Nouvelle-Aquitaine, France...
# 3106  (Bordeaux, Gironde, Nouvelle-Aquitaine, France...
# 1652  (South Australia, Australia, (-30.5343665, 135...
# 227   (South Australia, Australia, (-30.5343665, 135...
#
#                                      point        lat        long altitude
# 63          (43.9792797, -120.737257, 0.0)  43.979280 -120.737257      0.0
# 1522       (-30.5343665, 135.6301212, 0.0) -30.534367  135.630121      0.0
# 760         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 83    (45.8802348, 4.564533629559522, 0.0)  45.880235    4.564534      0.0
# 1446         (43.4586541, 11.1389204, 0.0)  43.458654   11.138920      0.0
# 775         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 3104          (44.841225, -0.5800364, 0.0)  44.841225   -0.580036      0.0
# 3106          (44.841225, -0.5800364, 0.0)  44.841225   -0.580036      0.0
# 1652       (-30.5343665, 135.6301212, 0.0) -30.534367  135.630121      0.0
# 227        (-30.5343665, 135.6301212, 0.0) -30.534367  135.630121      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Save files for use in other notebooks

# %%
df_Wine00.to_csv(path_or_buf = './Wine_Hier00.csv', index = False)
df_Wine01.to_csv(path_or_buf = './Wine_Hier01.csv', index = False)
