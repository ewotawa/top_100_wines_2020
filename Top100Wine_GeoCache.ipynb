# %% [markdown]
# # GeoCache: *Wine Spectator*'s Top 100 Wines, 1988-2020
# List available online on *Wine Spectator*'s [Top 100 Lists web site](https://top100.winespectator.com/lists/).

# %% [markdown]
# ## File Setup

# %%
# import and initialize main python libraries
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# import libraries for file navigation
import os
import shutil
import glob
from pandas_ods_reader import read_ods

# import other packages
from scipy import stats
from sklearn import linear_model

# import geo packages
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon

# import Geopy packages
import geopy
from geopy.geocoders import Nominatim

# %%
# initialize vizualization set
sns.set(style="whitegrid", palette="colorblind", color_codes=True)
sns.mpl.rc("figure", figsize=(10, 6))

# Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Dataframe Exploration

# %%
# Note: save CSV files in UTF-8 format to preserve special characters.
df_Wine = pd.read_csv('./CSV_Wines.csv')
df_GeoCache = pd.read_csv('./CSV_GeoCache.csv')
df_GeoList = pd.read_csv('./CSV_GeoList.csv')

# %%
df_Wine.shape
# Out:
# (3301, 18)

# %%
df_Wine.dtypes
# Out:
# Review_Year           float64
# Rank                   object
# Vintage                object
# Score                 float64
# Price                  object
# Winemaker              object
# Wine                   object
# Wine_Style             object
# Grape_Blend            object
# Blend_List             object
# Geography              object
# Cases_Made            float64
# Cases_Imported        float64
# Reviewer               object
# Drink_now             float64
# Best_Drink_from       float64
# Best_Drink_Through    float64
# Review                 object
# dtype: object

# %%
df_GeoCache.shape
# Out:
# (1226, 3)

# %%
df_GeoList.shape
# Out:
# (448, 1)

# %%
df_Wine.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price               Winemaker  \
# 2931       1991.0   32    1988   94.0    27   Château Pavie-Decesse
# 1228       2008.0   29    2005   96.0   100                A. Clape
# 1030       2010.0   31    2004   96.0    95              Terralsole
# 220        2018.0   21    2016   93.0    18              Scott Base
# 2760       1993.0   61    1990   91.0     9         Michele Chiarlo
# 2055       2000.0   56    1997   93.0    45                 Swanson
# 1720       2003.0   21    2000   92.0    13  Château de Flaugergues
# 2488       1996.0   89    1993   90.0    16               Saxenburg
# 1022       2010.0   23    2008   97.0    45                Owen Roe
# 1736       2003.0   37    2001   92.0    18              Dr. Loosen
#
#                                                    Wine Wine_Style  \
# 2931                                        St.-Emilion        Red
# 1228                                             Cornas        Red
# 1030                     Brunello di Montalcino Riserva        Red
# 220                            Pinot Noir Central Otago        Red
# 2760                                     Barbera d'Asti        Red
# 2055                                 Alexis Napa Valley        Red
# 1720  Coteaux du Languedoc La Méjanelle Cuvée Sommel...        Red
# 2488             Shiraz Stellenbosch Private Collection        Red
# 1022  Syrah Yakima Valley Red Willow Vineyard Chapel...        Red
# 1736  Riesling Kabinett Mosel-Saar-Ruwer Wehlener So...      White
#
#                  Grape_Blend                Blend_List  \
# 2931                   Blend        Bordeaux Blend Red
# 1228          Shiraz | Syrah                       NaN
# 1030  Brunello di Montalcino                       NaN
# 220               Pinot Noir                       NaN
# 2760                 Barbera                       NaN
# 2055     Cabernet Sauvignon                        NaN
# 1720                   Blend  Southern Rhone Red Blend
# 2488          Shiraz | Syrah                       NaN
# 1022          Shiraz | Syrah                       NaN
# 1736                Riesling                       NaN
#
#                    Geography  Cases_Made  Cases_Imported Reviewer  Drink_now  \
# 2931             St.-Emilion      4500.0             NaN      NaN        NaN
# 1228                  Cornas      1330.0             NaN       JM        NaN
# 1030  Brunello di Montalcino      1450.0             NaN       JS        NaN
# 220            Central Otago      5000.0             NaN       MW        1.0
# 2760          Barbera d'Asti     11000.0             NaN      NaN        1.0
# 2055             Napa Valley      3400.0             NaN       JL        NaN
# 1720               Languedoc      6000.0             NaN       KM        1.0
# 2488            Stellenbosch       800.0             NaN      NaN        1.0
# 1022           Yakima Valley       359.0             NaN       HS        1.0
# 1736                   Mosel      1000.0             NaN       BS        1.0
#
#       Best_Drink_from  Best_Drink_Through  \
# 2931           1996.0              2000.0
# 1228           2012.0              2028.0
# 1030           2011.0                 NaN
# 220            2018.0              2028.0
# 2760           1993.0              1996.0
# 2055           2002.0              2010.0
# 1720           2003.0              2005.0
# 2488           1996.0              1999.0
# 1022           2010.0              2016.0
# 1736           2003.0              2012.0
#
#                                                  Review
# 2931  Brilliantly concentrated from beginning to end...
# 1228  A dense, racy red, with a terrific beam of ras...
# 1030  This changes all the time as you taste it, wit...
# 220   Smooth, silky raspberry coulis and maraschino ...
# 2760  Peppery, spicy notes invigorate this smooth-te...
# 2055  Weaves together a complex array of rich black ...
# 1720  Full-bore, decadent red, with dark plum and bl...
# 2488  Gorgeous, deeply flavored red sporting the exu...
# 1022  Warm, inviting and impressive for the purity o...
# 1736  Gorgeous balance and grace in this peach- and ...

# %%
df_GeoCache.sample(10)
# Out:
#                    Geography     Hierarchy  \
# 428                 Mercurey  Hierarchy_01
# 592               Montefalco  Hierarchy_01
# 459       Charmes-Chambertin  Hierarchy_01
# 718                   Mudgee  Hierarchy_02
# 1059  Minervois La Livinière  Hierarchy_03
# 320         Dry Creek Valley  Hierarchy_00
# 16              Clare Valley  Hierarchy_00
# 1015     Corton Les Renardes  Hierarchy_03
# 220          Vallagarina IGT  Hierarchy_00
# 122   Mâcon-La Roche Vineuse  Hierarchy_00
#
#                                                 Address
# 428                                    Burgundy, France
# 592                                       Umbria, Italy
# 459                                    Burgundy, France
# 718                  Mudgee, New South Wales, Australia
# 1059  Minervois La Livinière, Minervois, Languedoc-R...
# 320                                                 USA
# 16                                            Australia
# 1015  Corton Grand Cru, Côte de Beaune, Burgundy, Fr...
# 220                                               Italy
# 122                                              France

# %%
df_GeoList.sample(10)
# Out:
#                                                Address
# 191                                   Kamptal, Austria
# 218                    Madeira Bual, Madeira, Portugal
# 382                          St.-Joseph, Rhône, France
# 7    Alexander Valley, Sonoma County, North Coast, ...
# 439                                    Washington, USA
# 402                                      Umbria, Italy
# 420                                Victoria, Australia
# 181          Hunter Valley, New South Wales, Australia
# 170                                             Greece
# 250   Morey-St.-Denis, Côte de Nuits, Burgundy, France

# %% [markdown]
# ### Geocode the Address dataframe
# Reference: [Python’s geocoding — Convert a list of addresses into a map](https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6)

# %%
# Initialize Nominatim into geolocator variable.
geolocator = Nominatim(user_agent='wine app')

# %%
geolocator.geocode('Castilla y León, Spain').raw
# Out:
# {'place_id': 258252333,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 349041,
#  'boundingbox': ['40.0824504', '43.2382034', '-7.077073', '-1.7753716'],
#  'lat': '41.8037172',
#  'lon': '-4.7471726',
#  'display_name': 'Castilla y León, España',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.9625997816800999,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}

# %%
geolocator.geocode('Castilla y León, Spain').point
# Out:
# Point(41.8037172, -4.7471726, 0.0)

# %%
# Apply geolocator to the Address column in the GeoList dataframe.
df_GeoList['loc'] = df_GeoList['Address'].apply(geolocator.geocode)

# %%
# Get .point containing lat/long from Geocode response, if not none.
df_GeoList['point'] = df_GeoList['loc'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# Split the .point column into separate columns for lat, long, and altitude
df_GeoList[['lat', 'long', 'altitude']] = pd.DataFrame(df_GeoList['point'].to_list(), index=df_GeoList.index)

# %%
df_GeoList
# Out:
#                                                Address  \
# 0                                       Abruzzo, Italy
# 1           Adelaide Hills, South Australia, Australia
# 2                               Aegean Islands, Greece
# 3             Aglianico del Vulture, Basilicata, Italy
# 4                           Agrelo, Mendoza, Argentina
# 5                     Alba, Piedmont | Piemonte, Italy
# 6                                   Alentejo, Portugal
# 7    Alexander Valley, Sonoma County, North Coast, ...
# 8                            Alicante, Valencia, Spain
# 9                   Almansa, Castilla La Mancha, Spain
# 10                                      Alsace, France
# 11   Alto Adige Terlano, Alto Adige, Sudtirol, Tren...
# 12    Alto Adige, Sudtirol, Trentino-Alto Adige, Italy
# 13    Alto Adige, Sudtirol, Trentino,Alto Adige, Italy
# 14    Amador County, Sierra Foothills, California, USA
# 15           Amarone della Valpolicella, Veneto, Italy
# 16                 Amyndaio, Macedonia, Greece, Greece
# 17                                    Andalucia, Spain
# 18   Anderson Valley, Mendocino County, North Coast...
# 19                                Anjou, Loire, France
# 20                     Apalta, Colchagua Valley, Chile
# 21                            Apremont, Savoie, France
# 22                                       Aragon, Spain
# 23                       Arbois Pupillin, Jura, France
# 24                                           Argentina
# 25   Arroyo Grande Valley, San Luis Obispo County, ...
# 26                               Auckland, New Zealand
# 27                                           Australia
# 28                                             Austria
# 29                            Bandol, Provence, France
# ..                                                 ...
# 418     Verdicchio dei Castelli di Jesi, Marche, Italy
# 419              Verona IGT, Veneto IGT, Veneto, Italy
# 420                                Victoria, Australia
# 421  Vigneti delle Dolomiti IGT, Trentino,Alto Adig...
# 422                      Vin de Corse, Corsica, France
# 423                               Vin de Pays , France
# 424       Vino Nobile di Montepulciano, Tuscany, Italy
# 425                           Vinsobres, Rhône, France
# 426           Volnay, Côte de Beaune, Burgundy, France
# 427  Vosne-Romanée Aux Brûlées, Vosne-Romanée Premi...
# 428  Vosne-Romanée Clos des Réas , Vosne-Romanée Pr...
# 429  Vosne-Romanée Cros Parantoux, Vosne-Romanée Pr...
# 430  Vosne-Romanée Les Beaux Monts, Vosne-Romanée P...
# 431  Vosne-Romanée Les Chaumes, Vosne-Romanée Premi...
# 432  Vosne-Romanée Premier Cru, Vosne-Romanée, Côte...
# 433     Vosne-Romanée, Côte de Nuits, Burgundy, France
# 434           Vougeot, Côte de Nuits, Burgundy, France
# 435                   Vouvray, Touraine, Loire, France
# 436                                    Wachau, Austria
# 437  Walker Bay, Cape South Coast, Western Cape, So...
# 438                Walla Walla Valley, Washington, USA
# 439                                    Washington, USA
# 440                       Western Australia, Australia
# 441                         Western Cape, South Africa
# 442                     Willamette Valley, Oregon, USA
# 443                     Yakima Valley, Washington, USA
# 444  Yamhill-Carlton District, Willamette Valley, O...
# 445                  Yarra Valley, Victoria, Australia
# 446  Yamhill-Carlton District, Willamette Valley, O...
# 447                  Yarra Valley, Victoria, Australia
#
#                                                    loc  \
# 0            (Abruzzo, Italia, (42.227681, 13.854983))
# 1    (Adelaide Hills Council, South Australia, Aust...
# 2    (Aegean, Σάμη - Αγία Ευφημία, Καραβόμυλος, Δήμ...
# 3                                                 None
# 4    (Agrelo, Distrito Agrelo, Departamento Luján d...
# 5                                                 None
# 6       (Alentejo, Portugal, (38.0551003, -7.8605799))
# 7                                                 None
# 8    (Alacant / Alicante, l'Alacantí, Alacant / Ali...
# 9    (Almansa, Albacete, Castilla-La Mancha, 02640,...
# 10   (Alsace, France métropolitaine, France, (48.24...
# 11                                                None
# 12   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 13   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 14                                                None
# 15                                                None
# 16                                                None
# 17       (Andalucía, España, (37.3399964, -4.5811614))
# 18                                                None
# 19   (Anjoux, Sagy, Louhans, Saône-et-Loire, Bourgo...
# 20   (Viña Apalta, Millahue de Apalta, Santa Cruz, ...
# 21   (Apremont, Chambéry, Savoie, Auvergne-Rhône-Al...
# 22          (Aragón, España, (41.3787291, -0.7639373))
# 23                                                None
# 24             (Argentina, (-34.9964963, -64.9672817))
# 25                                                None
# 26   (Auckland, Waitematā, Auckland, 1010, New Zeal...
# 27                 (Australia, (-24.7761086, 134.755))
# 28               (Österreich, (47.2000338, 13.199959))
# 29   (Bandol, Toulon, Var, Provence-Alpes-Côte d'Az...
# ..                                                 ...
# 418                                               None
# 419                                               None
# 420  (Victoria, Australia, (-36.5986096, 144.6780052))
# 421                                               None
# 422  (Les Plaisirs du Vin, Rue du Général de Gaulle...
# 423  (Le Bois Vien, Craon, Château-Gontier, Mayenne...
# 424                                               None
# 425  (Vinsobres, Nyons, Drôme, Auvergne-Rhône-Alpes...
# 426                                               None
# 427                                               None
# 428                                               None
# 429                                               None
# 430                                               None
# 431                                               None
# 432                                               None
# 433                                               None
# 434                                               None
# 435  (Rue de Vouvray, Auzouer-en-Touraine, Loches, ...
# 436  (Wachau, Bezirk Krems, Niederösterreich, Öster...
# 437                                               None
# 438  (Walla Walla, Walla Walla County, Washington, ...
# 439  (Washington, District of Columbia, United Stat...
# 440  (Western Australia, Australia, (-25.2303005, 1...
# 441  (Western Cape, South Africa, (-33.546977, 20.7...
# 442  (Willamette, West Linn, Metro, Oregon, 97068, ...
# 443  (Yakima, Yakima County, Washington, United Sta...
# 444                                               None
# 445  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
# 446                                               None
# 447  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
#
#                                              point        lat        long  \
# 0                      (42.227681, 13.854983, 0.0)  42.227681   13.854983
# 1    (-34.901351649999995, 138.8293202817461, 0.0) -34.901352  138.829320
# 2                    (38.2504094, 20.6304217, 0.0)  38.250409   20.630422
# 3                                             None        NaN         NaN
# 4                  (-33.1184629, -68.8859261, 0.0) -33.118463  -68.885926
# 5                                             None        NaN         NaN
# 6                    (38.0551003, -7.8605799, 0.0)  38.055100   -7.860580
# 7                                             None        NaN         NaN
# 8                     (38.353738, -0.4901846, 0.0)  38.353738   -0.490185
# 9                    (38.8682065, -1.0978627, 0.0)  38.868206   -1.097863
# 10             (48.24917645, 7.4074699518555, 0.0)  48.249176    7.407470
# 11                                            None        NaN         NaN
# 12          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 13          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 14                                            None        NaN         NaN
# 15                                            None        NaN         NaN
# 16                                            None        NaN         NaN
# 17                   (37.3399964, -4.5811614, 0.0)  37.339996   -4.581161
# 18                                            None        NaN         NaN
# 19                     (46.564187, 5.3193257, 0.0)  46.564187    5.319326
# 20                 (-34.6239248, -71.2671251, 0.0) -34.623925  -71.267125
# 21                         (45.5132, 5.95937, 0.0)  45.513200    5.959370
# 22                   (41.3787291, -0.7639373, 0.0)  41.378729   -0.763937
# 23                                            None        NaN         NaN
# 24                 (-34.9964963, -64.9672817, 0.0) -34.996496  -64.967282
# 25                                            None        NaN         NaN
# 26                  (-36.852095, 174.7631803, 0.0) -36.852095  174.763180
# 27                     (-24.7761086, 134.755, 0.0) -24.776109  134.755000
# 28                    (47.2000338, 13.199959, 0.0)  47.200034   13.199959
# 29                    (43.1357717, 5.7523647, 0.0)  43.135772    5.752365
# ..                                             ...        ...         ...
# 418                                           None        NaN         NaN
# 419                                           None        NaN         NaN
# 420                (-36.5986096, 144.6780052, 0.0) -36.598610  144.678005
# 421                                           None        NaN         NaN
# 422                   (41.5903081, 9.2780396, 0.0)  41.590308    9.278040
# 423                  (47.8653429, -0.9011409, 0.0)  47.865343   -0.901141
# 424                                           None        NaN         NaN
# 425                   (44.3339938, 5.0609674, 0.0)  44.333994    5.060967
# 426                                           None        NaN         NaN
# 427                                           None        NaN         NaN
# 428                                           None        NaN         NaN
# 429                                           None        NaN         NaN
# 430                                           None        NaN         NaN
# 431                                           None        NaN         NaN
# 432                                           None        NaN         NaN
# 433                                           None        NaN         NaN
# 434                                           None        NaN         NaN
# 435                   (47.5835908, 0.9204818, 0.0)  47.583591    0.920482
# 436           (48.3275563, 15.41162578949626, 0.0)  48.327556   15.411626
# 437                                           None        NaN         NaN
# 438                (46.0667277, -118.3393456, 0.0)  46.066728 -118.339346
# 439                 (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558
# 440                (-25.2303005, 121.0187246, 0.0) -25.230300  121.018725
# 441                    (-33.546977, 20.72753, 0.0) -33.546977   20.727530
# 442                (45.3442868, -122.6670374, 0.0)  45.344287 -122.667037
# 443                 (46.601557, -120.5108421, 0.0)  46.601557 -120.510842
# 444                                           None        NaN         NaN
# 445                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
# 446                                           None        NaN         NaN
# 447                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
#
#      altitude
# 0         0.0
# 1         0.0
# 2         0.0
# 3         NaN
# 4         0.0
# 5         NaN
# 6         0.0
# 7         NaN
# 8         0.0
# 9         0.0
# 10        0.0
# 11        NaN
# 12        0.0
# 13        0.0
# 14        NaN
# 15        NaN
# 16        NaN
# 17        0.0
# 18        NaN
# 19        0.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        NaN
# 24        0.0
# 25        NaN
# 26        0.0
# 27        0.0
# 28        0.0
# 29        0.0
# ..        ...
# 418       NaN
# 419       NaN
# 420       0.0
# 421       NaN
# 422       0.0
# 423       0.0
# 424       NaN
# 425       0.0
# 426       NaN
# 427       NaN
# 428       NaN
# 429       NaN
# 430       NaN
# 431       NaN
# 432       NaN
# 433       NaN
# 434       NaN
# 435       0.0
# 436       0.0
# 437       NaN
# 438       0.0
# 439       0.0
# 440       0.0
# 441       0.0
# 442       0.0
# 443       0.0
# 444       NaN
# 445       0.0
# 446       NaN
# 447       0.0
#
# [448 rows x 6 columns]

# %% [markdown]
# ### Append geography details to the GeoCache dataframe
# Determine how well populated geography is at different hierarchy levels.

# %%
df_GeoCache = pd.merge(df_GeoCache, df_GeoList, on = 'Address', how = 'left' )

# %%
df_GeoCache.to_csv(path_or_buf = './GeoCache.csv', index = False)

# %% [markdown]
# ### Append Hierarchy 00 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache00 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_00')
]

df_GeoCache00.sample(10)
# Out:
#                            Geography     Hierarchy    Address  \
# 1                             Agrelo  Hierarchy_00  Argentina
# 228            Morellino di Scansano  Hierarchy_00      Italy
# 266                      Jerez-Xérès  Hierarchy_00      Spain
# 306                      Lake County  Hierarchy_00        USA
# 168                             Nahe  Hierarchy_00    Germany
# 75   Chassagne-Montrachet En Remilly  Hierarchy_00     France
# 232                      Sant'Antimo  Hierarchy_00      Italy
# 175                          Naoussa  Hierarchy_00     Greece
# 189                          Taurasi  Hierarchy_00      Italy
# 45                      Maipo Valley  Hierarchy_00      Chile
#
#                                              loc  \
# 1        (Argentina, (-34.9964963, -64.9672817))
# 228            (Italia, (42.6384261, 12.674297))
# 266           (España, (39.3260685, -4.8379791))
# 306  (United States, (39.7837304, -100.4458825))
# 168      (Deutschland, (51.0834196, 10.4234469))
# 75              (France, (46.603354, 1.8883335))
# 232            (Italia, (42.6384261, 12.674297))
# 175           (Ελλάδα, (38.9953683, 21.9877132))
# 189            (Italia, (42.6384261, 12.674297))
# 45           (Chile, (-31.7613365, -71.3187697))
#
#                                point        lat        long  altitude
# 1    (-34.9964963, -64.9672817, 0.0) -34.996496  -64.967282       0.0
# 228     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 266    (39.3260685, -4.8379791, 0.0)  39.326068   -4.837979       0.0
# 306  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882       0.0
# 168    (51.0834196, 10.4234469, 0.0)  51.083420   10.423447       0.0
# 75       (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 232     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 175    (38.9953683, 21.9877132, 0.0)  38.995368   21.987713       0.0
# 189     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 45   (-31.7613365, -71.3187697, 0.0) -31.761336  -71.318770       0.0

# %%
df_Wine00 = pd.merge(df_Wine, df_GeoCache00, on = 'Geography', how = 'left')

df_Wine00.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price             Winemaker  \
# 1324       2007.0   23    2004   93.0    45  Bodega Catena Zapata
# 2431       1996.0   30    1994   96.0    27                Turley
# 2777       1993.0   75    1990   91.0    17           Clos Pegase
# 2013       2000.0   12    1997   96.0    52              Antinori
# 3199       1989.0   97    1985   91.0    21                  Simi
# 883        2012.0   82      NV   90.0    16         Emilio Lustau
# 386        2017.0   86    2014   94.0    75             Lancaster
# 3278       1988.0   76    1985   93.0    22              Sterling
# 2484       1996.0   83    1994   90.0    15             Bernardus
# 795        2013.0   94    2009   94.0    60            Schiavenza
#
#                                                    Wine           Wine_Style  \
# 1324                                Malbec Mendoza Alta                  Red
# 2431               Zinfandel Napa Valley Hayne Vineyard                  Red
# 2777                     Cabernet Sauvignon Napa Valley                  Red
# 2013  Bolgheri Superiore Guado al Tasso Tenuta Belve...                  Red
# 3199                   Cabernet Sauvignon Sonoma County                  Red
# 883          Amontillado Jerez Los Arcos Solera Reserva  Dessert & Fortified
# 386                 Cabernet Sauvignon Alexander Valley                  Red
# 3278                   Three Palms Vineyard Napa Valley                  Red
# 2484                         Chardonnay Monterey County                White
# 795                                        Barolo Prapò                  Red
#
#               Grape_Blend          Blend_List  ... Best_Drink_from  \
# 1324              Malbec                  NaN  ...          2007.0
# 2431            Zinfandel                 NaN  ...             NaN
# 2777  Cabernet Sauvignon                  NaN  ...          1993.0
# 2013                Blend  Bordeaux Blend Red  ...          2005.0
# 3199  Cabernet Sauvignon                  NaN  ...             NaN
# 883              Palomino                 NaN  ...          2012.0
# 386   Cabernet Sauvignon                  NaN  ...          2019.0
# 3278               Merlot                 NaN  ...          1993.0
# 2484          Chardonnay                  NaN  ...             NaN
# 795                 Blend            Nebbiolo  ...          2017.0
#
#       Best_Drink_Through                                             Review  \
# 1324              2010.0  Dark and lush, with a gorgeous mouthfeel to th...
# 2431                 NaN  Even more impressive than the first release fr...
# 2777              2002.0  Firm and intense with a solid core of cherry, ...
# 2013                 NaN  A balanced and harmonious young red. Dark ruby...
# 3199              1994.0  Ripe and delicious but elegantly contained in ...
# 883                  NaN  A more flattering style, with an off-dry edge ...
# 386               2029.0  A big, rich Cabernet, with firm, structured ta...
# 3278              1993.0  Loaded with fruit and concentrated flavors tha...
# 2484                 NaN  A bold, ripe and full-bodied white from Califo...
# 795               2032.0  Warm and generous, this red balances notes of ...
#
#          Hierarchy    Address                                          loc  \
# 1324  Hierarchy_00  Argentina      (Argentina, (-34.9964963, -64.9672817))
# 2431  Hierarchy_00        USA  (United States, (39.7837304, -100.4458825))
# 2777  Hierarchy_00        USA  (United States, (39.7837304, -100.4458825))
# 2013  Hierarchy_00      Italy            (Italia, (42.6384261, 12.674297))
# 3199  Hierarchy_00        USA  (United States, (39.7837304, -100.4458825))
# 883   Hierarchy_00      Spain           (España, (39.3260685, -4.8379791))
# 386   Hierarchy_00        USA  (United States, (39.7837304, -100.4458825))
# 3278  Hierarchy_00        USA  (United States, (39.7837304, -100.4458825))
# 2484  Hierarchy_00        USA  (United States, (39.7837304, -100.4458825))
# 795   Hierarchy_00      Italy            (Italia, (42.6384261, 12.674297))
#
#                                 point        lat        long altitude
# 1324  (-34.9964963, -64.9672817, 0.0) -34.996496  -64.967282      0.0
# 2431  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 2777  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 2013     (42.6384261, 12.674297, 0.0)  42.638426   12.674297      0.0
# 3199  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 883     (39.3260685, -4.8379791, 0.0)  39.326068   -4.837979      0.0
# 386   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 3278  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 2484  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 795      (42.6384261, 12.674297, 0.0)  42.638426   12.674297      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Append Hierarchy 01 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache01 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_01')
]

df_GeoCache01.sample(10)
# Out:
#                              Geography     Hierarchy  \
# 366                             Mudgee  Hierarchy_01
# 529                           Amyndaio  Hierarchy_01
# 493                          Montlouis  Hierarchy_01
# 650                Contra Costa County  Hierarchy_01
# 439                Pommard La Platière  Hierarchy_01
# 594                           Prosecco  Hierarchy_01
# 462                  Clos des Lambrays  Hierarchy_01
# 448  Puligny-Montrachet Les Folatières  Hierarchy_01
# 589       Vino Nobile di Montepulciano  Hierarchy_01
# 613                         Walker Bay  Hierarchy_01
#
#                         Address  \
# 366  New South Wales, Australia
# 529   Macedonia, Greece, Greece
# 493               Loire, France
# 650             California, USA
# 439            Burgundy, France
# 594               Veneto, Italy
# 462            Burgundy, France
# 448            Burgundy, France
# 589              Tuscany, Italy
# 613  Western Cape, South Africa
#
#                                                    loc  \
# 366  (New South Wales, Australia, (-31.8759835, 147...
# 529  (Border България (Bulgaria) - Ελλάδα (Greece),...
# 493  (Loire, Auvergne-Rhône-Alpes, France métropoli...
# 650  (California, United States, (36.7014631, -118....
# 439  (Bourgogne, France métropolitaine, France, (47...
# 594         (Veneto, Italia, (45.6476663, 11.8665254))
# 462  (Bourgogne, France métropolitaine, France, (47...
# 448  (Bourgogne, France métropolitaine, France, (47...
# 589        (Toscana, Italia, (43.4586541, 11.1389204))
# 613  (Western Cape, South Africa, (-33.546977, 20.7...
#
#                                      point        lat        long  altitude
# 366        (-31.8759835, 147.2869493, 0.0) -31.875984  147.286949       0.0
# 529          (41.7427066, 26.1770757, 0.0)  41.742707   26.177076       0.0
# 493  (45.75385355, 4.045473682551104, 0.0)  45.753854    4.045474       0.0
# 650         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997       0.0
# 439  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 594          (45.6476663, 11.8665254, 0.0)  45.647666   11.866525       0.0
# 462  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 448  (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486       0.0
# 589          (43.4586541, 11.1389204, 0.0)  43.458654   11.138920       0.0
# 613            (-33.546977, 20.72753, 0.0) -33.546977   20.727530       0.0

# %%
df_Wine01 = pd.merge(df_Wine, df_GeoCache01, on = 'Geography', how = 'left')

df_Wine01.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price            Winemaker  \
# 3237       1988.0   35    1985   97.0    90       Château Latour
# 965        2011.0   64    2008   95.0    70  Quinta do Vale Meão
# 1753       2003.0   52    1997   97.0    99               Lisini
# 2225       1998.0    8    1996   95.0    52              Argiano
# 3054       1990.0   52    1987   93.0    24         Clos du Bois
# 557        2015.0   57    2012   95.0    90             Altamura
# 360        2017.0   60    2015   90.0    25     Casa Santos Lima
# 2027       2000.0   26    1995   97.0   185             Penfolds
# 2162       1999.0   61    1997   91.0    18               Steele
# 1179       2009.0   78      NV   90.0    20        Gloria Ferrer
#
#                                                  Wine Wine_Style  \
# 3237                                         Pauillac        Red
# 965                                             Douro        Red
# 1753                   Brunello di Montalcino Ugolaia        Red
# 2225                                  Toscana Solengo        Red
# 3054  Chardonnay Alexander Valley Winemaker's Reserve      White
# 557                    Cabernet Sauvignon Napa Valley        Red
# 360                           Lisboa Colossal Reserva        Red
# 2027                    Shiraz South Australia Grange        Red
# 2162               Chardonnay California Steele Cuvée      White
# 1179                        Brut Sonoma County Sonoma  Sparkling
#
#                  Grape_Blend  \
# 3237                   Blend
# 965                    Blend
# 1753  Brunello di Montalcino
# 2225                   Blend
# 3054             Chardonnay
# 557      Cabernet Sauvignon
# 360                    Blend
# 2027          Shiraz | Syrah
# 2162             Chardonnay
# 1179                   Blend
#
#                                              Blend_List  ... Best_Drink_from  \
# 3237                        Cabernet Sauvignon – Merlot  ...             NaN
# 965   Touriga Nacional, Touriga Franca, Tinta Roriz ...  ...          2011.0
# 1753                                                NaN  ...          2005.0
# 2225  Sangiovese, Cabernet Sauvignon, Merlot and Syrah   ...          2000.0
# 3054                                                NaN  ...          1990.0
# 557                                                 NaN  ...          2015.0
# 360                                Portuguese Red Blend  ...          2017.0
# 2027                                                NaN  ...          2004.0
# 2162                                                NaN  ...          1999.0
# 1179                     85% Pinot Noir, 15% Chardonnay  ...          2009.0
#
#       Best_Drink_Through                                             Review  \
# 3237                 NaN  A majestic wine, a bit hard and lean, with str...
# 965               2020.0  Very fresh and pure-tasting, displaying a mine...
# 1753                 NaN  Fabulous bottle. Very, very classy aromas of f...
# 2225                 NaN  Wild thing. This Italian red is even better th...
# 3054              1993.0  A rich, smooth, creamy style that offers a bro...
# 557               2028.0  Amazingly pure, rich and complex, with tiers o...
# 360               2020.0  Plum and boysenberry notes weave together with...
# 2027              2020.0  A massive wine, majestic in its proportions,co...
# 2162              2001.0  Lots of up-front fruit and spice make this whi...
# 1179              2012.0  Lively and fun to drink, with creamy Asian pea...
#
#          Hierarchy                        Address  \
# 3237  Hierarchy_01               Bordeaux, France
# 965   Hierarchy_01                Douro, Portugal
# 1753  Hierarchy_01                 Tuscany, Italy
# 2225  Hierarchy_01                 Tuscany, Italy
# 3054  Hierarchy_01                California, USA
# 557   Hierarchy_01                California, USA
# 360   Hierarchy_01  Estremadura, Lisboa, Portugal
# 2027  Hierarchy_01     South Australia, Australia
# 2162  Hierarchy_01                California, USA
# 1179  Hierarchy_01                California, USA
#
#                                                     loc  \
# 3237  (Bordeaux, Gironde, Nouvelle-Aquitaine, France...
# 965   (Douro, Norte, Portugal, (41.17004195, -7.3047...
# 1753        (Toscana, Italia, (43.4586541, 11.1389204))
# 2225        (Toscana, Italia, (43.4586541, 11.1389204))
# 3054  (California, United States, (36.7014631, -118....
# 557   (California, United States, (36.7014631, -118....
# 360   (Rua da Estremadura, Vila Chã, Santo António d...
# 2027  (South Australia, Australia, (-30.5343665, 135...
# 2162  (California, United States, (36.7014631, -118....
# 1179  (California, United States, (36.7014631, -118....
#
#                                        point        lat        long altitude
# 3237            (44.841225, -0.5800364, 0.0)  44.841225   -0.580036      0.0
# 965   (41.17004195, -7.304749811735755, 0.0)  41.170042   -7.304750      0.0
# 1753           (43.4586541, 11.1389204, 0.0)  43.458654   11.138920      0.0
# 2225           (43.4586541, 11.1389204, 0.0)  43.458654   11.138920      0.0
# 3054          (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 557           (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 360             (38.635382, -9.0427141, 0.0)  38.635382   -9.042714      0.0
# 2027         (-30.5343665, 135.6301212, 0.0) -30.534367  135.630121      0.0
# 2162          (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 1179          (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Save files for use in other notebooks

# %%
df_Wine00.to_csv(path_or_buf = './Wine_Hier00.csv', index = False)
df_Wine01.to_csv(path_or_buf = './Wine_Hier01.csv', index = False)
