# %% [markdown]
# # GeoCache: *Wine Spectator*'s Top 100 Wines, 1988-2020
# List available online on *Wine Spectator*'s [Top 100 Lists web site](https://top100.winespectator.com/lists/).

# %% [markdown]
# ## File Setup

# %%
# import and initialize main python libraries
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# import libraries for file navigation
import os
import shutil
import glob
from pandas_ods_reader import read_ods

# import other packages
from scipy import stats
from sklearn import linear_model

# import geo packages
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon

# import Geopy packages
import geopy
from geopy.geocoders import Nominatim

# %%
# initialize vizualization set
sns.set(style="whitegrid", palette="colorblind", color_codes=True)
sns.mpl.rc("figure", figsize=(10, 6))

# Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Dataframe Exploration

# %%
# Note: save CSV files in UTF-8 format to preserve special characters.
df_Wine = pd.read_csv('./CSV_Wines.csv')
df_GeoCache = pd.read_csv('./CSV_GeoCache.csv')
df_GeoList = pd.read_csv('./CSV_GeoList.csv')

# %%
df_Wine.shape
# Out:
# (3301, 18)

# %%
df_Wine.dtypes
# Out:
# Review_Year           float64
# Rank                   object
# Vintage                object
# Score                 float64
# Price                  object
# Winemaker              object
# Wine                   object
# Wine_Style             object
# Grape_Blend            object
# Blend_List             object
# Geography              object
# Cases_Made            float64
# Cases_Imported        float64
# Reviewer               object
# Drink_now             float64
# Best_Drink_from       float64
# Best_Drink_Through    float64
# Review                 object
# dtype: object

# %%
df_GeoCache.shape
# Out:
# (1224, 3)

# %%
df_GeoList.shape
# Out:
# (445, 1)

# %%
df_Wine.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price                    Winemaker  \
# 1984       2001.0   85    1999   90.0    23          Fattoria di Felsina
# 2475       1996.0   76    1994   90.0    12                      J. Lohr
# 496        2016.0   97    2013   91.0    34                 Le Macchiole
# 37         2020.0   38    2017   94.0    35             Bodegas Juan Gil
# 485        2016.0   86    2012   93.0    36          Vigneti del Vulture
# 2995       1991.0   96    1982   90.0    14                 Lar de Lares
# 1685       2004.0   86    2002   90.0    12                 La Valentina
# 1025       2010.0   26    2005   94.0    35  Bodegas Resalte de Peñafiel
# 2519       1995.0   20    1992   93.0    30       Anderson's Conn Valley
# 2179       1999.0   80    1997   90.0    18          The Hess Collection
#
#                                                Wine Wine_Style  \
# 1984                    Chianti Classico Berardenga        Red
# 2475                 Chardonnay Monterey Riverstone      White
# 496                                        Bolgheri        Red
# 37                              Jumilla Blue Label         Red
# 485           Aglianico del Vulture Piano del Cerro        Red
# 2995                  Tierra de Barros Gran Reserva        Red
# 1685                        Montepulciano d'Abruzzo        Red
# 1025                       Ribera del Duero Crianza        Red
# 2519  Cabernet Sauvignon Napa Valley Estate Reserve        Red
# 2179                         Chardonnay Napa Valley      White
#
#               Grape_Blend                                   Blend_List  \
# 1984              Chianti                                          NaN
# 2475          Chardonnay                                           NaN
# 496                 Blend            Merlot, Cabernet Franc and Syrah
# 37                  Blend  Monastrell, Cabernet Sauvignon and Syrah.
# 485             Aglianico                                          NaN
# 2995          Tempranillo                                          NaN
# 1685        Montepulciano                                          NaN
# 1025          Tempranillo                                          NaN
# 2519  Cabernet Sauvignon                                           NaN
# 2179          Chardonnay                                           NaN
#
#                   Geography  Cases_Made  Cases_Imported Reviewer  Drink_now  \
# 1984                Chianti     14165.0             NaN       JS        NaN
# 2475               Monterey     86000.0             NaN      NaN        NaN
# 496                Bolgheri         NaN           900.0       BS        NaN
# 37                  Jumilla      2500.0          1250.0       TM        1.0
# 485   Aglianico del Vulture      5000.0             NaN       AN        1.0
# 2995    Ribera del Guadiana      3500.0             NaN      NaN        NaN
# 1685                Abruzzo     11600.0             NaN       JS        1.0
# 1025       Ribera del Duero      5000.0             NaN       TM        1.0
# 2519            Napa Valley      4243.0             NaN      NaN        NaN
# 2179            Napa Valley     30000.0             NaN       JL        1.0
#
#       Best_Drink_from  Best_Drink_Through  \
# 1984           2002.0              2005.0
# 2475              NaN                 NaN
# 496            2018.0              2024.0
# 37             2020.0              2032.0
# 485            2016.0              2027.0
# 2995              NaN                 NaN
# 1685           2004.0              2008.0
# 1025           2010.0              2016.0
# 2519           1999.0                 NaN
# 2179           1999.0              2003.0
#
#                                                  Review
# 1984  Lots of dried cherry and crushed black fruit, ...
# 2475  A complex array of elegant pear, spice, honey ...
# 496   Sleek and elegant, with concentrated flavors o...
# 37    This brawny red shows a savory character, with...
# 485   A dense and tarry red that glides on the silky...
# 2995  Distinctive, rich, mature and elegant, with pl...
# 1685  Plenty of soft and spicy character with hints ...
# 1025  Fresh and focused, this firm red delivers ripe...
# 2519  A beautifully crafted red with rich, complex c...
# 2179  Bright and inviting, the lively intensity of t...

# %%
df_GeoCache.sample(10)
# Out:
#                      Geography     Hierarchy  \
# 482              Côtes du Jura  Hierarchy_01
# 176         Macedonia – Greece  Hierarchy_00
# 1109  Spring Mountain District  Hierarchy_03
# 903       Valpolicella Ripasso  Hierarchy_02
# 710                     Agrelo  Hierarchy_02
# 1040         Gevrey-Chambertin  Hierarchy_03
# 792                  Marsannay  Hierarchy_02
# 943          Santa Ynez Valley  Hierarchy_02
# 74                      Beaune  Hierarchy_00
# 794               Clos de Tart  Hierarchy_02
#
#                                                 Address
# 482                                        Jura, France
# 176                                              Greece
# 1109          Napa County, North Coast, California, USA
# 903                         Valpolicella, Veneto, Italy
# 710                          Agrelo, Mendoza, Argentina
# 1040  Gevrey-Chambertin, Côte de Nuits, Burgundy, Fr...
# 792                     Côte de Nuits, Burgundy, France
# 943                      Central Coast, California, USA
# 74                                               France
# 794                     Côte de Nuits, Burgundy, France

# %%
df_GeoList.sample(10)
# Out:
#                                                Address
# 379          St.-Chinian, Languedoc-Roussillon, France
# 133  Côtes du Roussillon-Villages, Languedoc-Roussi...
# 88   Chassagne-Montrachet Morgeot, Chassagne-Montra...
# 320                     Rhodes, Aegean Islands, Greece
# 134  Crémant de Bourgogne, Bourgogne, Burgundy, France
# 149   Eola-Amity Hills, Willamette Valley, Oregon, USA
# 68   Carneros, Napa Valley, Napa County, North Coas...
# 6                                   Alentejo, Portugal
# 145  Edna Valley, San Luis Obispo County, Central C...
# 344                     San Rafael, Mendoza, Argentina

# %% [markdown]
# ### Geocode the Address dataframe
# Reference: [Python’s geocoding — Convert a list of addresses into a map](https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6)

# %%
# Initialize Nominatim into geolocator variable.
geolocator = Nominatim(user_agent='wine app')

# %%
geolocator.geocode('Castilla y León, Spain').raw
# Out:
# {'place_id': 258252333,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 349041,
#  'boundingbox': ['40.0824504', '43.2382034', '-7.077073', '-1.7753716'],
#  'lat': '41.8037172',
#  'lon': '-4.7471726',
#  'display_name': 'Castilla y León, España',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.9625997816800999,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}

# %%
geolocator.geocode('Castilla y León, Spain').point
# Out:
# Point(41.8037172, -4.7471726, 0.0)

# %%
# Apply geolocator to the Address column in the GeoList dataframe.
df_GeoList['loc'] = df_GeoList['Address'].apply(geolocator.geocode)

# %%
# Get .point containing lat/long from Geocode response, if not none.
df_GeoList['point'] = df_GeoList['loc'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# Split the .point column into separate columns for lat, long, and altitude
df_GeoList[['lat', 'long', 'altitude']] = pd.DataFrame(df_GeoList['point'].to_list(), index=df_GeoList.index)

# %%
df_GeoList
# Out:
#                                                Address  \
# 0                                       Abruzzo, Italy
# 1           Adelaide Hills, South Australia, Australia
# 2                               Aegean Islands, Greece
# 3             Aglianico del Vulture, Basilicata, Italy
# 4                           Agrelo, Mendoza, Argentina
# 5                     Alba, Piedmont | Piemonte, Italy
# 6                                   Alentejo, Portugal
# 7    Alexander Valley, Sonoma County, North Coast, ...
# 8                            Alicante, Valencia, Spain
# 9                   Almansa, Castilla La Mancha, Spain
# 10                                      Alsace, France
# 11   Alto Adige Terlano, Alto Adige, Sudtirol, Tren...
# 12    Alto Adige, Sudtirol, Trentino-Alto Adige, Italy
# 13    Alto Adige, Sudtirol, Trentino,Alto Adige, Italy
# 14    Amador County, Sierra Foothills, California, USA
# 15           Amarone della Valpolicella, Veneto, Italy
# 16                 Amyndaio, Macedonia, Greece, Greece
# 17                                    Andalucia, Spain
# 18   Anderson Valley, Mendocino County, North Coast...
# 19                                Anjou, Loire, France
# 20                     Apalta, Colchagua Valley, Chile
# 21                            Apremont, Savoie, France
# 22                                       Aragon, Spain
# 23                       Arbois Pupillin, Jura, France
# 24                                           Argentina
# 25   Arroyo Grande Valley, San Luis Obispo County, ...
# 26                               Auckland, New Zealand
# 27                                           Australia
# 28                                             Austria
# 29                            Bandol, Provence, France
# ..                                                 ...
# 415                                        Var, France
# 416                          Veneto IGT, Veneto, Italy
# 417                                      Veneto, Italy
# 418     Verdicchio dei Castelli di Jesi, Marche, Italy
# 419              Verona IGT, Veneto IGT, Veneto, Italy
# 420                                Victoria, Australia
# 421  Vigneti delle Dolomiti IGT, Trentino,Alto Adig...
# 422                      Vin de Corse, Corsica, France
# 423       Vino Nobile di Montepulciano, Tuscany, Italy
# 424                           Vinsobres, Rhône, France
# 425           Volnay, Côte de Beaune, Burgundy, France
# 426  Vosne-Romanée Aux Brûlées, Vosne-Romanée Premi...
# 427  Vosne-Romanée Clos des Réas , Vosne-Romanée Pr...
# 428  Vosne-Romanée Cros Parantoux, Vosne-Romanée Pr...
# 429  Vosne-Romanée Les Beaux Monts, Vosne-Romanée P...
# 430  Vosne-Romanée Les Chaumes, Vosne-Romanée Premi...
# 431  Vosne-Romanée Premier Cru, Vosne-Romanée, Côte...
# 432     Vosne-Romanée, Côte de Nuits, Burgundy, France
# 433           Vougeot, Côte de Nuits, Burgundy, France
# 434                   Vouvray, Touraine, Loire, France
# 435                                    Wachau, Austria
# 436  Walker Bay, Cape South Coast, Western Cape, So...
# 437                Walla Walla Valley, Washington, USA
# 438                                    Washington, USA
# 439                       Western Australia, Australia
# 440                         Western Cape, South Africa
# 441                     Willamette Valley, Oregon, USA
# 442                     Yakima Valley, Washington, USA
# 443  Yamhill-Carlton District, Willamette Valley, O...
# 444                  Yarra Valley, Victoria, Australia
#
#                                                    loc  \
# 0            (Abruzzo, Italia, (42.227681, 13.854983))
# 1    (Adelaide Hills Council, South Australia, Aust...
# 2    (Aegean, Σάμη - Αγία Ευφημία, Καραβόμυλος, Δήμ...
# 3                                                 None
# 4    (Agrelo, Distrito Agrelo, Departamento Luján d...
# 5                                                 None
# 6       (Alentejo, Portugal, (38.0551003, -7.8605799))
# 7                                                 None
# 8    (Alacant / Alicante, l'Alacantí, Alacant / Ali...
# 9    (Almansa, Albacete, Castilla-La Mancha, 02640,...
# 10   (Alsace, France métropolitaine, France, (48.24...
# 11                                                None
# 12   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 13   (Bolzano - Bozen, Trentino-Alto Adige/Südtirol...
# 14                                                None
# 15                                                None
# 16                                                None
# 17       (Andalucía, España, (37.3399964, -4.5811614))
# 18                                                None
# 19   (Anjoux, Sagy, Louhans, Saône-et-Loire, Bourgo...
# 20   (Viña Apalta, Millahue de Apalta, Santa Cruz, ...
# 21   (Apremont, Chambéry, Savoie, Auvergne-Rhône-Al...
# 22          (Aragón, España, (41.3787291, -0.7639373))
# 23                                                None
# 24             (Argentina, (-34.9964963, -64.9672817))
# 25                                                None
# 26   (Auckland, Waitematā, Auckland, 1010, New Zeal...
# 27                 (Australia, (-24.7761086, 134.755))
# 28               (Österreich, (47.2000338, 13.199959))
# 29   (Bandol, Toulon, Var, Provence-Alpes-Côte d'Az...
# ..                                                 ...
# 415  (Var, Provence-Alpes-Côte d'Azur, France métro...
# 416                                               None
# 417         (Veneto, Italia, (45.6476663, 11.8665254))
# 418                                               None
# 419                                               None
# 420  (Victoria, Australia, (-36.5986096, 144.6780052))
# 421                                               None
# 422  (Les Plaisirs du Vin, Rue du Général de Gaulle...
# 423                                               None
# 424  (Vinsobres, Nyons, Drôme, Auvergne-Rhône-Alpes...
# 425                                               None
# 426                                               None
# 427                                               None
# 428                                               None
# 429                                               None
# 430                                               None
# 431                                               None
# 432                                               None
# 433                                               None
# 434  (Rue de Vouvray, Auzouer-en-Touraine, Loches, ...
# 435  (Wachau, Bezirk Krems, Niederösterreich, Öster...
# 436                                               None
# 437  (Walla Walla, Walla Walla County, Washington, ...
# 438  (Washington, District of Columbia, United Stat...
# 439  (Western Australia, Australia, (-25.2303005, 1...
# 440  (Western Cape, South Africa, (-33.546977, 20.7...
# 441  (Willamette, West Linn, Metro, Oregon, 97068, ...
# 442  (Yakima, Yakima County, Washington, United Sta...
# 443                                               None
# 444  (Yarra, Murray Valley Highway, Yarrawonga, Shi...
#
#                                              point        lat        long  \
# 0                      (42.227681, 13.854983, 0.0)  42.227681   13.854983
# 1    (-34.901351649999995, 138.8293202817461, 0.0) -34.901352  138.829320
# 2                    (38.2504094, 20.6304217, 0.0)  38.250409   20.630422
# 3                                             None        NaN         NaN
# 4                  (-33.1184629, -68.8859261, 0.0) -33.118463  -68.885926
# 5                                             None        NaN         NaN
# 6                    (38.0551003, -7.8605799, 0.0)  38.055100   -7.860580
# 7                                             None        NaN         NaN
# 8                     (38.353738, -0.4901846, 0.0)  38.353738   -0.490185
# 9                    (38.8682065, -1.0978627, 0.0)  38.868206   -1.097863
# 10             (48.24917645, 7.4074699518555, 0.0)  48.249176    7.407470
# 11                                            None        NaN         NaN
# 12          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 13          (46.65594215, 11.229637264169462, 0.0)  46.655942   11.229637
# 14                                            None        NaN         NaN
# 15                                            None        NaN         NaN
# 16                                            None        NaN         NaN
# 17                   (37.3399964, -4.5811614, 0.0)  37.339996   -4.581161
# 18                                            None        NaN         NaN
# 19                     (46.564187, 5.3193257, 0.0)  46.564187    5.319326
# 20                 (-34.6239248, -71.2671251, 0.0) -34.623925  -71.267125
# 21                         (45.5132, 5.95937, 0.0)  45.513200    5.959370
# 22                   (41.3787291, -0.7639373, 0.0)  41.378729   -0.763937
# 23                                            None        NaN         NaN
# 24                 (-34.9964963, -64.9672817, 0.0) -34.996496  -64.967282
# 25                                            None        NaN         NaN
# 26                  (-36.852095, 174.7631803, 0.0) -36.852095  174.763180
# 27                     (-24.7761086, 134.755, 0.0) -24.776109  134.755000
# 28                    (47.2000338, 13.199959, 0.0)  47.200034   13.199959
# 29                    (43.1357717, 5.7523647, 0.0)  43.135772    5.752365
# ..                                             ...        ...         ...
# 415             (43.4173592, 6.2664620128919, 0.0)  43.417359    6.266462
# 416                                           None        NaN         NaN
# 417                  (45.6476663, 11.8665254, 0.0)  45.647666   11.866525
# 418                                           None        NaN         NaN
# 419                                           None        NaN         NaN
# 420                (-36.5986096, 144.6780052, 0.0) -36.598610  144.678005
# 421                                           None        NaN         NaN
# 422                   (41.5903081, 9.2780396, 0.0)  41.590308    9.278040
# 423                                           None        NaN         NaN
# 424                   (44.3339938, 5.0609674, 0.0)  44.333994    5.060967
# 425                                           None        NaN         NaN
# 426                                           None        NaN         NaN
# 427                                           None        NaN         NaN
# 428                                           None        NaN         NaN
# 429                                           None        NaN         NaN
# 430                                           None        NaN         NaN
# 431                                           None        NaN         NaN
# 432                                           None        NaN         NaN
# 433                                           None        NaN         NaN
# 434                   (47.5835908, 0.9204818, 0.0)  47.583591    0.920482
# 435           (48.3275563, 15.41162578949626, 0.0)  48.327556   15.411626
# 436                                           None        NaN         NaN
# 437                (46.0667277, -118.3393456, 0.0)  46.066728 -118.339346
# 438                 (38.8949924, -77.0365581, 0.0)  38.894992  -77.036558
# 439                (-25.2303005, 121.0187246, 0.0) -25.230300  121.018725
# 440                    (-33.546977, 20.72753, 0.0) -33.546977   20.727530
# 441                (45.3442868, -122.6670374, 0.0)  45.344287 -122.667037
# 442                 (46.601557, -120.5108421, 0.0)  46.601557 -120.510842
# 443                                           None        NaN         NaN
# 444                (-36.0154297, 146.0139795, 0.0) -36.015430  146.013980
#
#      altitude
# 0         0.0
# 1         0.0
# 2         0.0
# 3         NaN
# 4         0.0
# 5         NaN
# 6         0.0
# 7         NaN
# 8         0.0
# 9         0.0
# 10        0.0
# 11        NaN
# 12        0.0
# 13        0.0
# 14        NaN
# 15        NaN
# 16        NaN
# 17        0.0
# 18        NaN
# 19        0.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        NaN
# 24        0.0
# 25        NaN
# 26        0.0
# 27        0.0
# 28        0.0
# 29        0.0
# ..        ...
# 415       0.0
# 416       NaN
# 417       0.0
# 418       NaN
# 419       NaN
# 420       0.0
# 421       NaN
# 422       0.0
# 423       NaN
# 424       0.0
# 425       NaN
# 426       NaN
# 427       NaN
# 428       NaN
# 429       NaN
# 430       NaN
# 431       NaN
# 432       NaN
# 433       NaN
# 434       0.0
# 435       0.0
# 436       NaN
# 437       0.0
# 438       0.0
# 439       0.0
# 440       0.0
# 441       0.0
# 442       0.0
# 443       NaN
# 444       0.0
#
# [445 rows x 6 columns]

# %% [markdown]
# ### Append geography details to the GeoCache dataframe
# Determine how well populated geography is at different hierarchy levels.

# %%
df_GeoCache = pd.merge(df_GeoCache, df_GeoList, on = 'Address', how = 'left' )

# %%
df_GeoCache.to_csv(path_or_buf = './GeoCache.csv', index = False)

# %% [markdown]
# ### Append Hierarchy 00 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache00 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_00')
]

df_GeoCache00.sample(10)
# Out:
#                                 Geography     Hierarchy      Address  \
# 225                               Chianti  Hierarchy_00        Italy
# 348                     Côtes de Provence  Hierarchy_00       France
# 70                   Crémant de Bourgogne  Hierarchy_00       France
# 321                        Knights Valley  Hierarchy_00          USA
# 344                    Walla Walla Valley  Hierarchy_00          USA
# 76   Chassagne-Montrachet Les Chenevottes  Hierarchy_00       France
# 248                              Gisborne  Hierarchy_00  New Zealand
# 210                              Piemonte  Hierarchy_00        Italy
# 186                         Greco di Tufo  Hierarchy_00        Italy
# 34                       Niederösterreich  Hierarchy_00      Austria
#
#                                                    loc  \
# 225                  (Italia, (42.6384261, 12.674297))
# 348                   (France, (46.603354, 1.8883335))
# 70                    (France, (46.603354, 1.8883335))
# 321        (United States, (39.7837304, -100.4458825))
# 344        (United States, (39.7837304, -100.4458825))
# 76                    (France, (46.603354, 1.8883335))
# 248  (New Zealand / Aotearoa, (-41.5000831, 172.834...
# 210                  (Italia, (42.6384261, 12.674297))
# 186                  (Italia, (42.6384261, 12.674297))
# 34               (Österreich, (47.2000338, 13.199959))
#
#                                point        lat        long  altitude
# 225     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 348      (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 70       (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 321  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882       0.0
# 344  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882       0.0
# 76       (46.603354, 1.8883335, 0.0)  46.603354    1.888334       0.0
# 248  (-41.5000831, 172.8344077, 0.0) -41.500083  172.834408       0.0
# 210     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 186     (42.6384261, 12.674297, 0.0)  42.638426   12.674297       0.0
# 34      (47.2000338, 13.199959, 0.0)  47.200034   13.199959       0.0

# %%
df_Wine00 = pd.merge(df_Wine, df_GeoCache00, on = 'Geography', how = 'left')

df_Wine00.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price                Winemaker  \
# 1529       2005.0   28    2002   96.0    65                  Leeuwin
# 667        2014.0   66    2012   91.0    17                   Fowles
# 2197       1999.0   96    1996   90.0    25          Château d'Issan
# 2630       1994.0   28    1990   93.0    45            Paolo Scavino
# 784        2013.0   83    2010   96.0   130                   Caymus
# 1968       2001.0   67    1999   92.0    37                   Shafer
# 1807       2002.0    6    1999   94.0    50                 Duckhorn
# 140        2019.0   41    2017   93.0    24            Carol Shelton
# 1464       2006.0   63    2003   92.0    38  Château Prieuré-Lichine
# 1978       2001.0   77    1997   93.0    40                 Trimbach
#
#                                                    Wine Wine_Style  \
# 1529               Chardonnay Margaret River Art Series      White
# 667                       Shiraz Victoria Are You Game?        Red
# 2197                                            Margaux        Red
# 2630                              Barolo Bric dël Fiasc        Red
# 784    Cabernet Sauvignon Napa Valley Special Selection        Red
# 1968  Chardonnay Napa Valley Carneros Red Shoulder R...      White
# 1807                     Cabernet Sauvignon Napa Valley        Red
# 140                         Coquille Blanc Paso Robles       White
# 1464                                            Margaux        Red
# 1978               Riesling Alsace Cuvée Frédéric Émile      White
#
#               Grape_Blend                                         Blend_List  \
# 1529          Chardonnay                                                 NaN
# 667        Shiraz | Syrah                                                NaN
# 2197                Blend                                 Bordeaux Blend Red
# 2630                Blend                                           Nebbiolo
# 784   Cabernet Sauvignon                                                 NaN
# 1968          Chardonnay                                                 NaN
# 1807  Cabernet Sauvignon                                                 NaN
# 140                 Blend  Grenache Blanc, Roussanne, Viognier and Marsan...
# 1464                Blend                                 Bordeaux Blend Red
# 1978             Riesling                                                NaN
#
#       ... Best_Drink_from  Best_Drink_Through  \
# 1529  ...          2005.0              2020.0
# 667   ...          2014.0              2018.0
# 2197  ...          2000.0                 NaN
# 2630  ...          2000.0                 NaN
# 784   ...          2013.0              2025.0
# 1968  ...          2001.0              2005.0
# 1807  ...          2004.0              2012.0
# 140   ...          2019.0              2024.0
# 1464  ...          2011.0                 NaN
# 1978  ...          2001.0              2008.0
#
#                                                  Review     Hierarchy  \
# 1529  A wine of marvelous richness and unexpected su...  Hierarchy_00
# 667   Vivid, peppery and appealing, with cherry and ...  Hierarchy_00
# 2197  Plenty of blackberry, currant and cherry chara...  Hierarchy_00
# 2630  Tannic, flavorful and complex, cascading its l...  Hierarchy_00
# 784   A seductive style that's openly fruity, showin...  Hierarchy_00
# 1968  Sleek, rich and elegant, this Chardonnay offer...  Hierarchy_00
# 1807  Dusty berry, currant, anise and cedary oak aro...  Hierarchy_00
# 140   Fresh and spicy pear, lime and green apple fla...  Hierarchy_00
# 1464  Aromas of blackberry and smoke with hints of t...  Hierarchy_00
# 1978  Ultraseductive, this Riesling offers suave not...  Hierarchy_00
#
#         Address                                          loc  \
# 1529  Australia          (Australia, (-24.7761086, 134.755))
# 667   Australia          (Australia, (-24.7761086, 134.755))
# 2197     France             (France, (46.603354, 1.8883335))
# 2630      Italy            (Italia, (42.6384261, 12.674297))
# 784         USA  (United States, (39.7837304, -100.4458825))
# 1968        USA  (United States, (39.7837304, -100.4458825))
# 1807        USA  (United States, (39.7837304, -100.4458825))
# 140         USA  (United States, (39.7837304, -100.4458825))
# 1464     France             (France, (46.603354, 1.8883335))
# 1978     France             (France, (46.603354, 1.8883335))
#
#                                 point        lat        long altitude
# 1529      (-24.7761086, 134.755, 0.0) -24.776109  134.755000      0.0
# 667       (-24.7761086, 134.755, 0.0) -24.776109  134.755000      0.0
# 2197      (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 2630     (42.6384261, 12.674297, 0.0)  42.638426   12.674297      0.0
# 784   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 1968  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 1807  (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 140   (39.7837304, -100.4458825, 0.0)  39.783730 -100.445882      0.0
# 1464      (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
# 1978      (46.603354, 1.8883335, 0.0)  46.603354    1.888334      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Append Hierarchy 01 details to the df_Wine dataset

# %%
# filter df_GeoCache to Hierarchy_00

df_GeoCache01 = df_GeoCache[
    (df_GeoCache.Hierarchy == 'Hierarchy_01')
]

df_GeoCache01.sample(10)
# Out:
#                              Geography     Hierarchy  \
# 495                       Pouilly-Fumé  Hierarchy_01
# 651               Arroyo Grande Valley  Hierarchy_01
# 484       Côtes du Roussillon-Villages  Hierarchy_01
# 658                      Central Coast  Hierarchy_01
# 388                           Kremstal  Hierarchy_01
# 692                       Ribbon Ridge  Hierarchy_01
# 358                         San Rafael  Hierarchy_01
# 448  Puligny-Montrachet Les Folatières  Hierarchy_01
# 482                      Côtes du Jura  Hierarchy_01
# 551                         Sebino IGT  Hierarchy_01
#
#                           Address  \
# 495                 Loire, France
# 651               California, USA
# 484  Languedoc-Roussillon, France
# 658               California, USA
# 388             Kremstal, Austria
# 692                   Oregon, USA
# 358            Mendoza, Argentina
# 448              Burgundy, France
# 482                  Jura, France
# 551               Lombardy, Italy
#
#                                                    loc  \
# 495  (Loire, Auvergne-Rhône-Alpes, France métropoli...
# 651  (California, United States, (36.7014631, -118....
# 484  (Languedoc-Roussillon, France métropolitaine, ...
# 658  (California, United States, (36.7014631, -118....
# 388  (Inzersdorf im Kremstal, Bezirk Kirchdorf, Obe...
# 692  (Oregon, United States, (43.9792797, -120.7372...
# 358  (Mendoza, Argentina, (-34.787093049999996, -68...
# 448  (Bourgogne, France métropolitaine, France, (47...
# 482  (Jura, Bourgogne-Franche-Comté, France métropo...
# 551       (Lombardia, Italia, (45.5703694, 9.7732524))
#
#                                               point        lat        long  \
# 495           (45.75385355, 4.045473682551104, 0.0)  45.753854    4.045474
# 651                  (36.7014631, -118.755997, 0.0)  36.701463 -118.755997
# 484           (43.65420305, 3.674669940206605, 0.0)  43.654203    3.674670
# 658                  (36.7014631, -118.755997, 0.0)  36.701463 -118.755997
# 388                   (47.9263917, 14.0780469, 0.0)  47.926392   14.078047
# 692                  (43.9792797, -120.737257, 0.0)  43.979280 -120.737257
# 358  (-34.787093049999996, -68.43818677312292, 0.0) -34.787093  -68.438187
# 448           (47.27808725, 4.222486304306048, 0.0)  47.278087    4.222486
# 482    (46.783362499999996, 5.783285726354901, 0.0)  46.783362    5.783286
# 551                    (45.5703694, 9.7732524, 0.0)  45.570369    9.773252
#
#      altitude
# 495       0.0
# 651       0.0
# 484       0.0
# 658       0.0
# 388       0.0
# 692       0.0
# 358       0.0
# 448       0.0
# 482       0.0
# 551       0.0

# %%
df_Wine01 = pd.merge(df_Wine, df_GeoCache01, on = 'Geography', how = 'left')

df_Wine01.sample(10)
# Out:
#       Review_Year Rank Vintage  Score Price                 Winemaker  \
# 1509       2005.0    8    1999   96.0   125            Castello Banfi
# 2004       2000.0    3    1997   97.0    60            Whitehall Lane
# 2016       2000.0   15    1998   95.0    29         Domaine Santa Duc
# 892        2012.0   91    2010   93.0    58              Kosta Browne
# 1524       2005.0   23    1999   97.0    99  Marchesi de' Frescobaldi
# 1804       2002.0    3    1997   94.0    50            Castello Banfi
# 863        2012.0   62    2009   91.0    19              Viña Ninquén
# 679        2014.0   78    2012   90.0    20                   Acrobat
# 2045       2000.0   44    1997   95.0    70                     Etude
# 2847       1992.0   45    1990   92.0    16                Ravenswood
#
#                                                    Wine Wine_Style  \
# 1509      Brunello di Montalcino Poggio all'Oro Riserva        Red
# 2004             Cabernet Sauvignon Napa Valley Reserve        Red
# 2016                                           Gigondas        Red
# 892                     Pinot Noir Russian River Valley        Red
# 1524  Brunello di Montalcino Castelgiocondo Ripe al ...        Red
# 1804                             Brunello di Montalcino        Red
# 863                         Syrah Colchagua Valley Antu        Red
# 679                                   Pinot Noir Oregon        Red
# 2045                     Cabernet Sauvignon Napa Valley        Red
# 2847                    Zinfandel Napa Valley Dickerson        Red
#
#                  Grape_Blend                Blend_List  ... Best_Drink_from  \
# 1509  Brunello di Montalcino                       NaN  ...          2005.0
# 2004     Cabernet Sauvignon                        NaN  ...          2002.0
# 2016                   Blend  Southern Rhone Red Blend  ...          2003.0
# 892               Pinot Noir                       NaN  ...          2013.0
# 1524  Brunello di Montalcino                       NaN  ...          2006.0
# 1804  Brunello di Montalcino                       NaN  ...          2003.0
# 863           Shiraz | Syrah                       NaN  ...          2012.0
# 679               Pinot Noir                       NaN  ...          2014.0
# 2045     Cabernet Sauvignon                        NaN  ...          2002.0
# 2847               Zinfandel                       NaN  ...          1992.0
#
#       Best_Drink_Through                                             Review  \
# 1509              2015.0  Intense aromas of smoke and coffee open to lay...
# 2004              2012.0  Deliciously ripe, rich and deeply flavored, wi...
# 2016              2020.0  Distinguished, deep and complex Rhône, offerin...
# 892               2023.0  Rich and expressive, with bold layers of ripe ...
# 1524                 NaN  Very structured. Superattractive aromas of plu...
# 1804                 NaN  A Brunello for everyone. Solid and focused, wi...
# 863               2015.0  This dark, ripe red delivers jammy layered fla...
# 679               2016.0  The crisp tannins and sleek structure give the...
# 2045              2016.0  Great structure, deliciously rich and complex,...
# 2847              1997.0  A delicious young Zin that is ripe, rich tanni...
#
#          Hierarchy                  Address  \
# 1509  Hierarchy_01           Tuscany, Italy
# 2004  Hierarchy_01          California, USA
# 2016  Hierarchy_01            Rhône, France
# 892   Hierarchy_01          California, USA
# 1524  Hierarchy_01           Tuscany, Italy
# 1804  Hierarchy_01           Tuscany, Italy
# 863   Hierarchy_01  Colchagua Valley, Chile
# 679   Hierarchy_01              Oregon, USA
# 2045  Hierarchy_01          California, USA
# 2847  Hierarchy_01          California, USA
#
#                                                     loc  \
# 1509        (Toscana, Italia, (43.4586541, 11.1389204))
# 2004  (California, United States, (36.7014631, -118....
# 2016  (Rhône, Circonscription départementale du Rhôn...
# 892   (California, United States, (36.7014631, -118....
# 1524        (Toscana, Italia, (43.4586541, 11.1389204))
# 1804        (Toscana, Italia, (43.4586541, 11.1389204))
# 863   (Colchagua, Palmilla, Provincia de Colchagua, ...
# 679   (Oregon, United States, (43.9792797, -120.7372...
# 2045  (California, United States, (36.7014631, -118....
# 2847  (California, United States, (36.7014631, -118....
#
#                                      point        lat        long altitude
# 1509         (43.4586541, 11.1389204, 0.0)  43.458654   11.138920      0.0
# 2004        (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 2016  (45.8802348, 4.564533629559522, 0.0)  45.880235    4.564534      0.0
# 892         (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 1524         (43.4586541, 11.1389204, 0.0)  43.458654   11.138920      0.0
# 1804         (43.4586541, 11.1389204, 0.0)  43.458654   11.138920      0.0
# 863         (-34.548228, -71.4013194, 0.0) -34.548228  -71.401319      0.0
# 679         (43.9792797, -120.737257, 0.0)  43.979280 -120.737257      0.0
# 2045        (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
# 2847        (36.7014631, -118.755997, 0.0)  36.701463 -118.755997      0.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Save files for use in other notebooks

# %%
# Remove duplicates by index: 2017 (46), 2015 (73), 1995 (94)
df_Wine00 = df_Wine00.drop([df_Wine00.index[2596], df_Wine00.index[574], df_Wine00.index[346]])
df_Wine01 = df_Wine01.drop([df_Wine00.index[2596], df_Wine00.index[574], df_Wine00.index[346]])

# %%
df_Wine00.shape
# Out:
# (3301, 25)

# %%
df_Wine01.shape
# Out:
# (3301, 25)

# %%
df_Wine00.to_csv(path_or_buf = './Wine_Hier00.csv', index = False)
df_Wine01.to_csv(path_or_buf = './Wine_Hier01.csv', index = False)
